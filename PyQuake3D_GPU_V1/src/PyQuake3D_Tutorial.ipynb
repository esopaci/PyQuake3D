# %% [markdown]
# ## PyQuake3D Usage Tutorial
#
# This Jupyter Notebook provides a step-by-step guide to installing and using **PyQuake3D**, a Python-based Boundary Element Method (BEM) tool for 3D earthquake sequence simulations with seismic and aseismic slip. We'll cover installation, compilation, setup, and running a simple simulation.
#
# **Features:**
# - 3D non-planar quasi-dynamic earthquake cycle simulations
# - Support for rate-and-state aging friction laws
# - Support for Hierarchical matrix storage and calculation
# - Support for GPU acceleration via CuPy
# - MPI acceleration support
# - Suitable for large model earthquake cycle simulation
#
# **Note:** MPI simulations may not run seamlessly in Jupyter due to their multi-process nature. We will first show how to install the simplest single-CPU version using conda on Windows, then how to install the GPU driver and cupy, finally how to run MPI-accelerated PyQuake3D on Linux system.

# %% [markdown]
# ## Step 1: Set Up Conda environment
#
# 1. Download from https://www.anaconda.com/docs/getting-started/miniconda/install
# 2. Then install it using exe program.
# 3. Open miniconda Prompt and navigate to the working directory(e.g. E:\work) using:
# E:
# then
# cd E:\work
#
# 3. After installation, create a new environment:
# conda create -n PyQuake3D python=3.12
# 4. Activate the environment:
# conda activate PyQuake3D
# 5. Install Jupyter notebook using: conda install jupyter notebook, then you can open the PyQuake3D_Tutorial.ipynb

# %% [markdown]
# ## Step 2: Install Python Dependencies
#
# **For single GPU/CPU verison**
# 1. Download from https://github.com/Computational-Geophysics/PyQuake3D
#
# 2. Install PyQuake3D using pip: pip install -r dependences.txt (make sure PyQuake3D environment is activated)
#
# **Notes**:PyQuake3D supports Python 3.8 and above, so there is no need to specify a specific version when installing the library.

# %% [markdown]
# ## Step 3: Runging a simple case (For single GPU/CPU verison).
# The easiest way to run pyquake3d is to run the single CPU version of Pyquake3D, without installing cupy.
# 1. Setup mesh model using Gmesh.
# 2. Setup parameter.txt.
# 3. Read model and mesh parameter(Please refer to mannul for specific meanning).
# 4. Calculating Green functions.
# 5. Calculating Qusi-Dynamic model.
# 6. Export results.
# The msh model and parameter.txt have been prepared at folder bp5t_3k

# %%
#Let runing PyQuake3D
#First Import all sub-functions

import readmsh
import numpy as np
import sys
import matplotlib.pyplot as plt
import QDsim
from math import *
import time
import argparse
import os
import psutil
from datetime import datetime
process = psutil.Process(os.getpid())

# %%
#Second,read the model file, parameter file, and create a basic class, then it start to calculate greenfunctions

fnamegeo='../bp5t_3k/bp5t.msh'
fnamePara='../bp5t_3k/parameter.txt'
nodelst,elelst=readmsh.read_mshV2(fnamegeo)
sim0=QDsim.QDsim(elelst,nodelst,fnamePara)
# Out:
# Cs 3464.0
# First Lamé constants 32038120320.0
# Shear Modulus 32038120320.0
# Youngs Modulus 80095300800.0
# Poissons ratio 0.25
# [40. 40. 40. ... 40. 40. 40.]
# L: 0.1
# maximum element size 1249.392905015399
# average elesize 1009.2986930015212
# Critical nucleation size 9436.005321762927
# Cohesive zone: 2359.0013304407316
# Start to load core functions...
# Core functions load completed.

# %% [markdown]
# **Note**
# 1. The Green function calculation is saved in the Corefunc directory defined in parameter.txt. The next time you start the program, you no longer need to calculate the Green function.
# 2. msh files are generated by *Gmesh*, link https://gmsh.info/. For convenience, We have created a simple 3D vertical plane geometry for simulating earthquake cycles on a strike-slip fault (bp5t.msh), and have set appropriate parameters (stress, friction parameters, etc).
# 3. Make sure to export version 2 of mesh file if you create your model.

# %%
#Third Calculating Qusi-Dynamic model

start_time=time.time()
    
totaloutputsteps=int(sim0.Para0['totaloutputsteps']) # The total time step of the simulation
directory='../outvtk'
if not os.path.exists(directory):  # The output directory
    os.mkdir(directory)

# Outputs the state of the system (including sliding velocity, time step, etc.) to track the state of the simulation, 
# and more importantly, to record the time and step.
f=open('state.txt','w')  
f.write('iteration time_step(s) maximum_slip1_rate(m/s) maximum_slip2_rate(m/s) time(s) time(h)\n')


if(sim0.useGPU==False):  #CPU case make sure to set GPU:True in parameter.txt
    for i in range(totaloutputsteps): 
        print('iteration:',i)

        #update adaptive time step
        if(i==0):
            dttry=sim0.htry
        else:
            dttry=dtnext

        # Qusi-Dynamic model update
        dttry,dtnext=sim0.simu_forward(dttry)
        year=sim0.time/3600/24/365
        print('dt:',dttry,' max_vel:',np.max(np.abs(sim0.slipv)),' Seconds:',sim0.time,'  Days:',sim0.time/3600/24,
            'year',year)
        f.write('%d %f %.16e %.16e %f %f\n' %(i,dttry,np.max(np.abs(sim0.slipv1)),np.max(np.abs(sim0.slipv2)),sim0.time,sim0.time/3600.0/24.0))

        # Get the memory info
        memory_info = process.memory_info()
        print(f"Memory usage: {memory_info.rss / (1024 ** 2)} MB")

        # Output vtk files for virualization
        if(sim0.Para0['outputvtk']=='True'):
            outsteps=int(sim0.Para0['outsteps']) #output steps
            if(i%outsteps==0):
                fname=directory+'/step'+str(i)+'.vtk'
                sim0.ouputVTK(fname)

end_time = time.time()
timetake=end_time-start_time
f.write('Program end time: %s\n'%str(datetime.now()))
f.write("Time taken: %.2f seconds\n"%timetake)
# Out:
# iteration: 0
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.00628881074529572 0.003425374049744081 0.002480440446272418 0.002800921316504449
# dt: 0.001  max_vel: 0.5774558242063524  Seconds: 3512883709.451269   Days: 40658.376266797095 year 111.39281168985505
# Memory usage: 936.66796875 MB
# iteration: 1
# foward time taken: 0.002995 seconds
#
# condition1,condition2,hnew1,hnew2: 0.014006902448989987 0.007623806015902206 0.0031700444193670583 0.003580134980728701
# dt: 0.0015  max_vel: 0.5777544067920883  Seconds: 3512883709.4527693   Days: 40658.376266814455 year 111.39281168990262
# Memory usage: 936.78125 MB
# iteration: 2
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.031047702343846597 0.016882582285148346 0.004055264019007771 0.004580756985134393
# dt: 0.0022500000000000003  max_vel: 0.5782021788555454  Seconds: 3512883709.4550195   Days: 40658.3762668405 year 111.39281168997398
# Memory usage: 936.78125 MB
# iteration: 3
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.06833768101082469 0.037108932385946106 0.00519498429716427 0.005869763381971516
# dt: 0.0033750000000000004  max_vel: 0.5788735998979616  Seconds: 3512883709.4583945   Days: 40658.37626687957 year 111.392811690081
# Memory usage: 936.78125 MB
# iteration: 4
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.14890290333463352 0.08070886830928035 0.006668480913981758 0.007537430038822433
# dt: 0.005062500000000001  max_vel: 0.5798801743942731  Seconds: 3512883709.463457   Days: 40658.37626693816 year 111.39281169024154
# Memory usage: 936.78125 MB
# iteration: 5
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.25113594495961344 0.13604692553796655 0.007912024919669147 0.008943997632503057
# dt: 0.006668480913981758  max_vel: 0.5812035577906288  Seconds: 3512883709.4701257   Days: 40658.376267015345 year 111.392811690453
# Memory usage: 936.78125 MB
# iteration: 6
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.34668563043579576 0.18788646019650046 0.008801222242457964 0.00994835006697436
# dt: 0.007912024919669147  max_vel: 0.5827684214532518  Seconds: 3512883709.478038   Days: 40658.37626710692 year 111.3928116907039
# Memory usage: 936.78125 MB
# iteration: 7
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.4238812904748081 0.23019981867884817 0.009404520284500444 0.010625870081091547
# dt: 0.008801222242457964  max_vel: 0.5845224988496883  Seconds: 3512883709.4868393   Days: 40658.37626720879 year 111.39281169098298
# Memory usage: 936.78125 MB
# iteration: 8
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 0.4821012065053371 0.2618881105963145 0.009793806365478913 0.011065116746373548
# dt: 0.009404520284500444  max_vel: 0.5864117564314784  Seconds: 3512883709.496244   Days: 40658.37626731764 year 111.3928116912812
# Memory usage: 936.78125 MB
# iteration: 9
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5235866128603912 0.28408279130608743 0.010032203103512643 0.011337179880917442
# dt: 0.009793806365478913  max_vel: 0.588367975769217  Seconds: 3512883709.5060377   Days: 40658.37626743099 year 111.39281169159176
# Memory usage: 936.78125 MB
# iteration: 10
# foward time taken: 0.003092 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5512574679420318 0.2987237794576132 0.01017110009284518 0.011497008866955136
# dt: 0.010032203103512643  max_vel: 0.5903591460360744  Seconds: 3512883709.51607   Days: 40658.3762675471 year 111.39281169190987
# Memory usage: 936.78125 MB
# iteration: 11
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5688437020251382 0.30829367240479066 0.010247356534353503 0.011582905560483381
# dt: 0.01017110009284518  max_vel: 0.5923640772141838  Seconds: 3512883709.526241   Days: 40658.376267664826 year 111.3928116922324
# Memory usage: 936.78125 MB
# iteration: 12
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5805652974282495 0.3150333191798345 0.01028215488733829 0.011619382765118662
# dt: 0.010247356534353503  max_vel: 0.5943693016895552  Seconds: 3512883709.536488   Days: 40658.376267783424 year 111.39281169255733
# Memory usage: 936.78125 MB
# iteration: 13
# foward time taken: 0.003985 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5886681206086465 0.31900364283844695 0.010288511507565174 0.011629673510983604
# dt: 0.01028215488733829  max_vel: 0.5963658098147139  Seconds: 3512883709.54677   Days: 40658.37626790243 year 111.39281169288337
# Memory usage: 936.78125 MB
# iteration: 14
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5927952161198122 0.321790065685769 0.010280497198355871 0.011616639996144585
# dt: 0.010288511507565174  max_vel: 0.598456834342125  Seconds: 3512883709.557059   Days: 40658.376268021515 year 111.39281169320962
# Memory usage: 936.78125 MB
# iteration: 15
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5965176909269255 0.3238043548628613 0.010259636238724166 0.011593113598376852
# dt: 0.010280497198355871  max_vel: 0.6005682401698051  Seconds: 3512883709.5673394   Days: 40658.3762681405 year 111.3928116935356
# Memory usage: 936.7890625 MB
# iteration: 16
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5987433990422881 0.3247704456084852 0.01023119411685997 0.011562697717968766
# dt: 0.010259636238724166  max_vel: 0.6026644430259621  Seconds: 3512883709.577599   Days: 40658.37626825925 year 111.39281169386096
# Memory usage: 936.796875 MB
# iteration: 17
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5993715015543275 0.32466274977194665 0.010200691565144996 0.01153140808190839
# dt: 0.01023119411685997  max_vel: 0.6047429106379028  Seconds: 3512883709.58783   Days: 40658.376268377666 year 111.39281169418538
# Memory usage: 936.796875 MB
# iteration: 18
# foward time taken: 0.002995 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5985731720185776 0.32378894173424383 0.010172991368375019 0.011503227875481047
# dt: 0.010200691565144996  max_vel: 0.6068099322005637  Seconds: 3512883709.5980306   Days: 40658.376268495726 year 111.39281169450884
# Memory usage: 936.796875 MB
# iteration: 19
# foward time taken: 0.002988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5968670057975183 0.32243308469999143 0.010151159951789536 0.011481622554281706
# dt: 0.010172991368375019  max_vel: 0.6089069246319395  Seconds: 3512883709.6082034   Days: 40658.376268613465 year 111.39281169483141
# Memory usage: 936.796875 MB
# iteration: 20
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5945944071641881 0.3212136759236336 0.010137106669846118 0.011465668337249173
# dt: 0.010151159951789536  max_vel: 0.6109850757157227  Seconds: 3512883709.618355   Days: 40658.37626873096 year 111.39281169515331
# Memory usage: 936.796875 MB
# iteration: 21
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5938300175169167 0.3225853273850002 0.010125677626050728 0.011440041606188311
# dt: 0.010137106669846118  max_vel: 0.6130453136395485  Seconds: 3512883709.628492   Days: 40658.37626884829 year 111.39281169547476
# Memory usage: 936.8046875 MB
# iteration: 22
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.596766359638594 0.3244934725831348 0.010104288533869545 0.011413672658933434
# dt: 0.010125677626050728  max_vel: 0.6150874535319473  Seconds: 3512883709.6386175   Days: 40658.376268965476 year 111.39281169579583
# Memory usage: 936.8046875 MB
# iteration: 23
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5989271289410194 0.3251914802379766 0.01007565878657785 0.011384669223918852
# dt: 0.010104288533869545  max_vel: 0.6171843808156062  Seconds: 3512883709.6487217   Days: 40658.37626908243 year 111.39281169611624
# Memory usage: 936.8046875 MB
# iteration: 24
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.599098414453553 0.32481377005483175 0.010046535589078701 0.011355050620095038
# dt: 0.01007565878657785  max_vel: 0.6193533264117979  Seconds: 3512883709.6587973   Days: 40658.37626919904 year 111.39281169643573
# Memory usage: 936.8046875 MB
# iteration: 25
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5979864928045703 0.3237486037367323 0.010021219195254734 0.011329669878362005
# dt: 0.010046535589078701  max_vel: 0.6215067463610024  Seconds: 3512883709.6688437   Days: 40658.37626931532 year 111.3928116967543
# Memory usage: 936.8046875 MB
# iteration: 26
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5960621932699058 0.3260564276783796 0.010002412381166613 0.011285076769991968
# dt: 0.010021219195254734  max_vel: 0.6236446392515894  Seconds: 3512883709.678865   Days: 40658.37626943131 year 111.39281169707209
# Memory usage: 936.8046875 MB
# iteration: 27
# foward time taken: 0.002973 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6035528193002986 0.33114721094786725 0.009958735746820182 0.011229050755768388
# dt: 0.010002412381166613  max_vel: 0.6257675286517161  Seconds: 3512883709.6888676   Days: 40658.37626954708 year 111.39281169738926
# Memory usage: 936.8046875 MB
# iteration: 28
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6099989627319813 0.33420393279933547 0.009894204872008674 0.011159491527346861
# dt: 0.009958735746820182  max_vel: 0.627869167270138  Seconds: 3512883709.6988263   Days: 40658.37626966234 year 111.39281169770504
# Memory usage: 936.828125 MB
# iteration: 29
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.612966353240186 0.33535219586085646 0.009820556101771153 0.011079576929402356
# dt: 0.009894204872008674  max_vel: 0.6299488217757407  Seconds: 3512883709.7087207   Days: 40658.37626977686 year 111.3928116980188
# Memory usage: 936.828125 MB
# iteration: 30
# foward time taken: 0.003988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6136140972225094 0.3352344884894592 0.009745396752070094 0.010997876842924645
# dt: 0.009820556101771153  max_vel: 0.6320365697421937  Seconds: 3512883709.718541   Days: 40658.37626989053 year 111.3928116983302
# Memory usage: 936.828125 MB
# iteration: 31
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6127482618952546 0.33429669537838547 0.00967354411477825 0.010919823465599008
# dt: 0.009745396752070094  max_vel: 0.634095629433608  Seconds: 3512883709.7282867   Days: 40658.37627000332 year 111.39281169863924
# Memory usage: 936.828125 MB
# iteration: 32
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6109177908162492 0.3328418275736714 0.00960796851995443 0.010848771108318443
# dt: 0.00967354411477825  max_vel: 0.6361699544719709  Seconds: 3512883709.7379603   Days: 40658.37627011528 year 111.39281169894598
# Memory usage: 936.828125 MB
# iteration: 33
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.608489765829997 0.33107205093128017 0.00955044098388613 0.010786724260112754
# dt: 0.00960796851995443  max_vel: 0.6382779595357775  Seconds: 3512883709.747568   Days: 40658.37627022649 year 111.39281169925064
# Memory usage: 936.828125 MB
# iteration: 34
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.605705382234447 0.3297144631535829 0.009501969851525353 0.010730954045628033
# dt: 0.00955044098388613  max_vel: 0.6403610398142627  Seconds: 3512883709.7571187   Days: 40658.37627033702 year 111.39281169955349
# Memory usage: 936.828125 MB
# iteration: 35
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6043796299704219 0.32915811639267545 0.009457888589518659 0.010680098150289625
# dt: 0.009501969851525353  max_vel: 0.642420524370589  Seconds: 3512883709.7666206   Days: 40658.376270447 year 111.39281169985479
# Memory usage: 936.828125 MB
# iteration: 36
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.60345507324341 0.32835182927911255 0.009416894713324662 0.010635767017396424
# dt: 0.009457888589518659  max_vel: 0.6445807208963397  Seconds: 3512883709.7760787   Days: 40658.376270556466 year 111.3928117001547
# Memory usage: 936.828125 MB
# iteration: 37
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.60241512457539 0.3281606437428374 0.009379313469366407 0.010590901409403533
# dt: 0.009416894713324662  max_vel: 0.646743482376723  Seconds: 3512883709.7854958   Days: 40658.37627066546 year 111.39281170045331
# Memory usage: 936.828125 MB
# iteration: 38
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6020719736034721 0.3275332529074646 0.009342946844456792 0.010552672997006081
# dt: 0.009379313469366407  max_vel: 0.6488866514159694  Seconds: 3512883709.794875   Days: 40658.37627077402 year 111.39281170075073
# Memory usage: 936.828125 MB
# iteration: 39
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6006670322395636 0.32633651253420615 0.009311070783051779 0.010519455331408715
# dt: 0.009342946844456792  max_vel: 0.65101002789987  Seconds: 3512883709.8042183   Days: 40658.37627088215 year 111.392811701047
# Memory usage: 936.828125 MB
# iteration: 40
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5985936488993198 0.32478646839290704 0.00928572283950733 0.010493552803806
# dt: 0.009311070783051779  max_vel: 0.6531141457543367  Seconds: 3512883709.8135295   Days: 40658.376270989924 year 111.39281170134225
# Memory usage: 936.828125 MB
# iteration: 41
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.596108637653264 0.3230238521897552 0.00926815190290097 0.010476381566479169
# dt: 0.00928572283950733  max_vel: 0.6551999702433416  Seconds: 3512883709.8228154   Days: 40658.376271097404 year 111.39281170163673
# Memory usage: 936.828125 MB
# iteration: 42
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5933769255662955 0.32113880685069307 0.009259115930393117 0.010468804622294294
# dt: 0.00926815190290097  max_vel: 0.6572687034510678  Seconds: 3512883709.8320837   Days: 40658.376271204674 year 111.39281170193061
# Memory usage: 936.828125 MB
# iteration: 43
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.590502357812354 0.3192696290152937 0.00925907717580609 0.010470815560129843
# dt: 0.009259115930393117  max_vel: 0.6593216608705625  Seconds: 3512883709.841343   Days: 40658.37627131184 year 111.39281170222422
# Memory usage: 936.828125 MB
# iteration: 44
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5893634035867882 0.3224562611254652 0.009262614306302982 0.010449994230088735
# dt: 0.00925907717580609  max_vel: 0.6613601941013837  Seconds: 3512883709.850602   Days: 40658.376271419 year 111.39281170251782
# Memory usage: 936.828125 MB
# iteration: 45
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5967428800907161 0.327925764522592 0.009243121050470518 0.010418878702681395
# dt: 0.009262614306302982  max_vel: 0.6634134157359802  Seconds: 3512883709.8598647   Days: 40658.37627152621 year 111.39281170281154
# Memory usage: 936.828125 MB
# iteration: 46
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6039822892810595 0.3314172252852836 0.009201450822862256 0.010374952923271414
# dt: 0.009243121050470518  max_vel: 0.6654701105083443  Seconds: 3512883709.8691077   Days: 40658.37627163319 year 111.39281170310463
# Memory usage: 936.828125 MB
# iteration: 47
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6075186512537657 0.3328733315375047 0.009149279514647878 0.010319128445476078
# dt: 0.009201450822862256  max_vel: 0.6675061491579376  Seconds: 3512883709.8783092   Days: 40658.37627173969 year 111.3928117033964
# Memory usage: 936.828125 MB
# iteration: 48
# foward time taken: 0.002988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6085852467354349 0.3329790595403992 0.00909421298564436 0.01025996834042389
# dt: 0.009149279514647878  max_vel: 0.6695292011260401  Seconds: 3512883709.8874583   Days: 40658.376271845584 year 111.39281170368653
# Memory usage: 936.83203125 MB
# iteration: 49
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.608037110797394 0.332208272375931 0.009041107086306874 0.010202944917205576
# dt: 0.00909421298564436  max_vel: 0.6715199721460188  Seconds: 3512883709.8965526   Days: 40658.37627195084 year 111.3928117039749
# Memory usage: 936.83203125 MB
# iteration: 50
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6064547640717344 0.3308819753605789 0.008992996828461308 0.010151483210925577
# dt: 0.009041107086306874  max_vel: 0.6734781053924731  Seconds: 3512883709.905594   Days: 40658.37627205549 year 111.3928117042616
# Memory usage: 936.83203125 MB
# iteration: 51
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6042254106289565 0.3295437304550458 0.00895173366808475 0.010105652005708772
# dt: 0.008992996828461308  max_vel: 0.6754038966403342  Seconds: 3512883709.914587   Days: 40658.37627215957 year 111.39281170454677
# Memory usage: 936.83203125 MB
# iteration: 52
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6027501170816801 0.32899745535932967 0.008915017527099138 0.010062621893841318
# dt: 0.00895173366808475  max_vel: 0.6772980031077678  Seconds: 3512883709.9235387   Days: 40658.37627226318 year 111.39281170483063
# Memory usage: 936.83203125 MB
# iteration: 53
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6019317376771076 0.3280997711896394 0.00888086487604079 0.01002682708002099
# dt: 0.008915017527099138  max_vel: 0.6791605374875296  Seconds: 3512883709.9324536   Days: 40658.37627236636 year 111.39281170511332
# Memory usage: 936.83203125 MB
# iteration: 54
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6002248613972759 0.3274571047026557 0.008851868950306435 0.009992332757419143
# dt: 0.00888086487604079  max_vel: 0.681130796670993  Seconds: 3512883709.9413347   Days: 40658.376272469155 year 111.39281170539495
# Memory usage: 936.83203125 MB
# iteration: 55
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5995910207245115 0.32792168489469004 0.008824832297774761 0.00995688423482108
# dt: 0.008851868950306435  max_vel: 0.6831351874128014  Seconds: 3512883709.9501867   Days: 40658.37627257161 year 111.39281170567564
# Memory usage: 936.83203125 MB
# iteration: 56
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6011237135033066 0.3287213481564324 0.008793387229437984 0.009921638256964642
# dt: 0.008824832297774761  max_vel: 0.6851195841882124  Seconds: 3512883709.9590116   Days: 40658.37627267374 year 111.39281170595545
# Memory usage: 936.83203125 MB
# iteration: 57
# foward time taken: 0.002509 seconds
#
# condition1,condition2,hnew1,hnew2: 0.60172061589961 0.3285832378778393 0.008760315138910629 0.00988711593870558
# dt: 0.008793387229437984  max_vel: 0.6870845715277012  Seconds: 3512883709.967805   Days: 40658.37627277552 year 111.3928117062343
# Memory usage: 936.83203125 MB
# iteration: 58
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6009154351334959 0.3283148584907804 0.008729704981700288 0.009851540143707512
# dt: 0.008760315138910629  max_vel: 0.6890729997728912  Seconds: 3512883709.9765654   Days: 40658.376272876914 year 111.39281170651209
# Memory usage: 936.83203125 MB
# iteration: 59
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6008257596851936 0.3280713794984694 0.008699461444078968 0.009818573772217006
# dt: 0.008729704981700288  max_vel: 0.6910401526944222  Seconds: 3512883709.9852953   Days: 40658.376272977956 year 111.39281170678892
# Memory usage: 936.83203125 MB
# iteration: 60
# foward time taken: 0.004017 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6000785030781411 0.327509402383916 0.008671480729094764 0.009787913498704517
# dt: 0.008699461444078968  max_vel: 0.6929854640988269  Seconds: 3512883709.9939947   Days: 40658.37627307864 year 111.39281170706477
# Memory usage: 936.83203125 MB
# iteration: 61
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5993887076762189 0.3278006724529669 0.008645578558471596 0.00975469746701312
# dt: 0.008671480729094764  max_vel: 0.6949087697070322  Seconds: 3512883710.002666   Days: 40658.376273179005 year 111.39281170733975
# Memory usage: 936.83203125 MB
# iteration: 62
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5998590630456967 0.32792580962088597 0.008618401568148398 0.009724817298754683
# dt: 0.008645578558471596  max_vel: 0.6968098272208278  Seconds: 3512883710.0113115   Days: 40658.37627327907 year 111.39281170761389
# Memory usage: 936.83203125 MB
# iteration: 63
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5999829607150691 0.3280002993598685 0.00859095515366336 0.009693807411734059
# dt: 0.008618401568148398  max_vel: 0.698687617812594  Seconds: 3512883710.01993   Days: 40658.37627337882 year 111.39281170788718
# Memory usage: 936.83203125 MB
# iteration: 64
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5997560499555128 0.32740397099057456 0.008564244035290249 0.009666453650127292
# dt: 0.00859095515366336  max_vel: 0.7005648067163517  Seconds: 3512883710.028521   Days: 40658.37627347826 year 111.39281170815961
# Memory usage: 936.83203125 MB
# iteration: 65
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5984124070296534 0.32673622759824866 0.008541446509121486 0.009640334098561321
# dt: 0.008564244035290249  max_vel: 0.7027105099814049  Seconds: 3512883710.0370855   Days: 40658.37627357738 year 111.39281170843117
# Memory usage: 936.83203125 MB
# iteration: 66
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5984258215552919 0.3276303544119258 0.00851867147663275 0.009609418517919972
# dt: 0.008541446509121486  max_vel: 0.7048369356473211  Seconds: 3512883710.045627   Days: 40658.37627367624 year 111.39281170870201
# Memory usage: 936.83203125 MB
# iteration: 67
# foward time taken: 0.003022 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5997677987505111 0.32789127293430226 0.008492151832899314 0.009582270088698552
# dt: 0.00851867147663275  max_vel: 0.7069432739725426  Seconds: 3512883710.054146   Days: 40658.37627377484 year 111.39281170897216
# Memory usage: 936.83203125 MB
# iteration: 68
# foward time taken: 0.003982 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5994457297621248 0.327779820282241 0.00846662424096817 0.009553088856536208
# dt: 0.008492151832899314  max_vel: 0.7090277623667615  Seconds: 3512883710.062638   Days: 40658.376273873124 year 111.39281170924143
# Memory usage: 936.83203125 MB
# iteration: 69
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 0.599605721158242 0.32807370284383214 0.008440722869722016 0.00952266510078119
# dt: 0.00846662424096817  max_vel: 0.7110898122522618  Seconds: 3512883710.0711045   Days: 40658.37627397112 year 111.39281170950991
# Memory usage: 936.83203125 MB
# iteration: 70
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5997804158907368 0.3276979015210775 0.008414410487328095 0.009495709478480694
# dt: 0.008440722869722016  max_vel: 0.7131284804720579  Seconds: 3512883710.079545   Days: 40658.3762740688 year 111.39281170977755
# Memory usage: 936.83203125 MB
# iteration: 71
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5987062874207221 0.32664830073270357 0.008391187788693492 0.00947218395153196
# dt: 0.008414410487328095  max_vel: 0.7151428050579537  Seconds: 3512883710.0879593   Days: 40658.3762741662 year 111.39281171004438
# Memory usage: 936.83203125 MB
# iteration: 72
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5968392820046634 0.3251766272613577 0.008373257940715565 0.009454576612695593
# dt: 0.008391187788693492  max_vel: 0.7171326551392233  Seconds: 3512883710.0963507   Days: 40658.37627426332 year 111.39281171031047
# Memory usage: 936.83203125 MB
# iteration: 73
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5944778959224665 0.32344726451509453 0.008361993722675322 0.009444441544356155
# dt: 0.008373257940715565  max_vel: 0.7190983854201394  Seconds: 3512883710.104724   Days: 40658.376274360235 year 111.39281171057598
# Memory usage: 936.83203125 MB
# iteration: 74
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5918144336209 0.3215658130944002 0.008358247672484508 0.009442747405751406
# dt: 0.008361993722675322  max_vel: 0.7210406127834803  Seconds: 3512883710.1130857   Days: 40658.37627445701 year 111.39281171084113
# Memory usage: 936.83203125 MB
# iteration: 75
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5889705081345697 0.3213151636228724 0.008362555936879375 0.009439989282132633
# dt: 0.008358247672484508  max_vel: 0.7229705630551849  Seconds: 3512883710.121444   Days: 40658.37627455375 year 111.39281171110618
# Memory usage: 936.83203125 MB
# iteration: 76
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5907801985400071 0.3245673609737255 0.008361734217227917 0.009425851130549485
# dt: 0.008362555936879375  max_vel: 0.724906608455305  Seconds: 3512883710.129807   Days: 40658.376274650545 year 111.39281171137135
# Memory usage: 936.83203125 MB
# iteration: 77
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5959252466024368 0.326856559623689 0.008346425314632124 0.009411685957803657
# dt: 0.008361734217227917  max_vel: 0.7268197050059871  Seconds: 3512883710.138169   Days: 40658.37627474732 year 111.3928117116365
# Memory usage: 936.83203125 MB
# iteration: 78
# foward time taken: 0.003305 seconds
#
# condition1,condition2,hnew1,hnew2: 0.598035558072082 0.3274809062545913 0.008325256436184314 0.009390869908417249
# dt: 0.008346425314632124  max_vel: 0.728705408680713  Seconds: 3512883710.1465154   Days: 40658.376274843926 year 111.39281171190116
# Memory usage: 936.83203125 MB
# iteration: 79
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.598152299960446 0.3280232501658622 0.008303817077399642 0.009363952533465943
# dt: 0.008325256436184314  max_vel: 0.7305613655724594  Seconds: 3512883710.1548405   Days: 40658.37627494028 year 111.39281171216516
# Memory usage: 936.83203125 MB
# iteration: 80
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5992150608216051 0.3282161742961073 0.008279492917832058 0.00933874006269851
# dt: 0.008303817077399642  max_vel: 0.7323865270610888  Seconds: 3512883710.163144   Days: 40658.37627503639 year 111.39281171242847
# Memory usage: 936.83203125 MB
# iteration: 81
# foward time taken: 0.003020 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5995730277220116 0.3284319483198123 0.008254254039216393 0.009310160524772682
# dt: 0.008279492917832058  max_vel: 0.7341792734221719  Seconds: 3512883710.1714234   Days: 40658.376275132214 year 111.392811712691
# Memory usage: 936.8359375 MB
# iteration: 82
# foward time taken: 0.004012 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5995556360399267 0.33002630459717774 0.00822913983852111 0.00927279436840651
# dt: 0.008254254039216393  max_vel: 0.7359384478882716  Seconds: 3512883710.1796775   Days: 40658.37627522775 year 111.39281171295274
# Memory usage: 936.8359375 MB
# iteration: 83
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6033624617096035 0.33280031587037656 0.008193723311090192 0.00922911815132547
# dt: 0.00822913983852111  max_vel: 0.7376631307289689  Seconds: 3512883710.1879067   Days: 40658.376275323 year 111.39281171321369
# Memory usage: 936.8359375 MB
# iteration: 84
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6068401557578937 0.3341824893603879 0.008149086761131439 0.00918178387468734
# dt: 0.008193723311090192  max_vel: 0.7393502310882447  Seconds: 3512883710.1961   Days: 40658.376275417824 year 111.39281171347349
# Memory usage: 936.8359375 MB
# iteration: 85
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6078435771463236 0.33420572826673495 0.0081020157794419 0.009131637716513928
# dt: 0.008149086761131439  max_vel: 0.7409970384451475  Seconds: 3512883710.2042494   Days: 40658.37627551215 year 111.39281171373192
# Memory usage: 936.8359375 MB
# iteration: 86
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6072293308280579 0.3333478012763819 0.008056845691614042 0.009083559705847776
# dt: 0.0081020157794419  max_vel: 0.7426604796823069  Seconds: 3512883710.2123513   Days: 40658.37627560592 year 111.39281171398883
# Memory usage: 936.8359375 MB
# iteration: 87
# foward time taken: 0.003985 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6055787450278036 0.3319320850886388 0.008016290196415057 0.009040609454454066
# dt: 0.008056845691614042  max_vel: 0.7447992772796151  Seconds: 3512883710.220408   Days: 40658.37627569917 year 111.3928117142443
# Memory usage: 936.77734375 MB
# iteration: 88
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6032792776489451 0.3306895419589672 0.007982009834170854 0.009001851576207988
# dt: 0.008016290196415057  max_vel: 0.7469111940729108  Seconds: 3512883710.228424   Days: 40658.37627579195 year 111.39281171449848
# Memory usage: 936.77734375 MB
# iteration: 89
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6018999533686704 0.32968910601336276 0.007951515429725556 0.008968789860490664
# dt: 0.007982009834170854  max_vel: 0.7489974705642355  Seconds: 3512883710.236406   Days: 40658.37627588433 year 111.39281171475159
# Memory usage: 936.77734375 MB
# iteration: 90
# foward time taken: 0.003985 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6002682794688563 0.3283055504438986 0.007925439163529075 0.00894204333948737
# dt: 0.007951515429725556  max_vel: 0.7510586667736903  Seconds: 3512883710.2443576   Days: 40658.37627597636 year 111.39281171500373
# Memory usage: 936.77734375 MB
# iteration: 91
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.598019926312506 0.3265969495451908 0.007905379351584748 0.008922024700813713
# dt: 0.007925439163529075  max_vel: 0.7530954938677954  Seconds: 3512883710.252283   Days: 40658.37627606809 year 111.39281171525505
# Memory usage: 936.77734375 MB
# iteration: 92
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5953928445434264 0.32469458221941505 0.007892316666391444 0.008909846377656796
# dt: 0.007905379351584748  max_vel: 0.7551090532243977  Seconds: 3512883710.2601886   Days: 40658.37627615959 year 111.39281171550573
# Memory usage: 936.77734375 MB
# iteration: 93
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5925391453876955 0.32268207312255487 0.007886850387127175 0.008906191807299952
# dt: 0.007892316666391444  max_vel: 0.757100658570241  Seconds: 3512883710.2680807   Days: 40658.376276250936 year 111.39281171575598
# Memory usage: 936.77734375 MB
# iteration: 94
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5895539421794511 0.3217496234807161 0.00788935325015437 0.008905175900673828
# dt: 0.007886850387127175  max_vel: 0.7590717246540692  Seconds: 3512883710.2759676   Days: 40658.37627634222 year 111.39281171600608
# Memory usage: 936.77734375 MB
# iteration: 95
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5905953456810172 0.3260241274853092 0.007889071782106237 0.008884519879447718
# dt: 0.00788935325015437  max_vel: 0.7610236989898912  Seconds: 3512883710.283857   Days: 40658.37627643353 year 111.39281171625626
# Memory usage: 936.77734375 MB
# iteration: 96
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5981536438927612 0.3296595498549755 0.007868752158433223 0.008864521238498855
# dt: 0.007889071782106237  max_vel: 0.7629553055665417  Seconds: 3512883710.291746   Days: 40658.37627652484 year 111.39281171650642
# Memory usage: 936.77734375 MB
# iteration: 97
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6018902986257026 0.33118385104068715 0.007838715590135166 0.008833535234300314
# dt: 0.007868752158433223  max_vel: 0.764861089864739  Seconds: 3512883710.299615   Days: 40658.37627661591 year 111.39281171675593
# Memory usage: 936.77734375 MB
# iteration: 98
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6030821369894116 0.33131060550577873 0.007805704815912042 0.008799142461458026
# dt: 0.007838715590135166  max_vel: 0.7667684670600692  Seconds: 3512883710.3074536   Days: 40658.376276706644 year 111.3928117170045
# Memory usage: 936.77734375 MB
# iteration: 99
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6026103418698613 0.33053103771269465 0.007774049777086725 0.008766216329198533
# dt: 0.007805704815912042  max_vel: 0.7687770694729269  Seconds: 3512883710.3152595   Days: 40658.37627679698 year 111.392811717252
# Memory usage: 936.77734375 MB
# iteration: 100
# foward time taken: 0.003092 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6010703525865548 0.32931038678669056 0.007746486441590263 0.00873712885486127
# dt: 0.007774049777086725  max_vel: 0.7707582378679053  Seconds: 3512883710.3230333   Days: 40658.37627688696 year 111.39281171749852
# Memory usage: 936.77734375 MB
# iteration: 101
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5997296919035223 0.32938137853236504 0.0077224688357284 0.008705775547101991
# dt: 0.007746486441590263  max_vel: 0.7727126396315002  Seconds: 3512883710.33078   Days: 40658.376276976625 year 111.39281171774418
# Memory usage: 936.77734375 MB
# iteration: 102
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6000806752262493 0.3290589141586368 0.00769762492090132 0.008680484016612224
# dt: 0.0077224688357284  max_vel: 0.7746407818100941  Seconds: 3512883710.3385024   Days: 40658.376277066 year 111.39281171798905
# Memory usage: 936.77734375 MB
# iteration: 103
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5990856726849362 0.32800730514444404 0.007675407962406277 0.008658099087764957
# dt: 0.00769762492090132  max_vel: 0.7765420624252791  Seconds: 3512883710.3462   Days: 40658.37627715509 year 111.39281171823312
# Memory usage: 936.77734375 MB
# iteration: 104
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5972331039851377 0.32805269218345623 0.0076579972020049195 0.008632871103195036
# dt: 0.007675407962406277  max_vel: 0.7784167535558429  Seconds: 3512883710.353875   Days: 40658.37627724393 year 111.39281171847652
# Memory usage: 936.77734375 MB
# iteration: 105
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5988373175751753 0.32954674469485606 0.007636527877519319 0.008605464306293529
# dt: 0.0076579972020049195  max_vel: 0.7802656441982384  Seconds: 3512883710.361533   Days: 40658.37627733256 year 111.39281171871934
# Memory usage: 936.77734375 MB
# iteration: 106
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.600758547679791 0.33007945773812514 0.007610241859357191 0.008578567078821214
# dt: 0.007636527877519319  max_vel: 0.7821397663596653  Seconds: 3512883710.3691697   Days: 40658.376277420946 year 111.3928117189615
# Memory usage: 936.77734375 MB
# iteration: 107
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6007779334310158 0.32957338685379 0.007583997376767274 0.008551662282754556
# dt: 0.007610241859357191  max_vel: 0.7840019968337625  Seconds: 3512883710.37678   Days: 40658.37627750903 year 111.39281171920283
# Memory usage: 936.77734375 MB
# iteration: 108
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5995693803242018 0.3288944108555206 0.007560887818330808 0.008525687007221899
# dt: 0.007583997376767274  max_vel: 0.7858360820045703  Seconds: 3512883710.384364   Days: 40658.376277596806 year 111.3928117194433
# Memory usage: 936.77734375 MB
# iteration: 109
# foward time taken: 0.003988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5990905571393375 0.3290333779994664 0.007539053218351708 0.008498989890484083
# dt: 0.007560887818330808  max_vel: 0.7876424542602974  Seconds: 3512883710.391925   Days: 40658.376277684314 year 111.39281171968305
# Memory usage: 936.77734375 MB
# iteration: 110
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5992598199376513 0.32861359126344436 0.007516856969204841 0.008476610233252696
# dt: 0.007539053218351708  max_vel: 0.7894210816047597  Seconds: 3512883710.399464   Days: 40658.376277771575 year 111.39281171992212
# Memory usage: 936.77734375 MB
# iteration: 111
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5981566570322954 0.3277803059795456 0.007497488493472938 0.008455946464526872
# dt: 0.007516856969204841  max_vel: 0.7911715449290189  Seconds: 3512883710.406981   Days: 40658.37627785857 year 111.39281172016048
# Memory usage: 936.77734375 MB
# iteration: 112
# foward time taken: 0.003988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5971963216395644 0.3276213367613399 0.00748057346732952 0.008434976592805517
# dt: 0.007497488493472938  max_vel: 0.7928941801378068  Seconds: 3512883710.4144783   Days: 40658.37627794535 year 111.39281172039821
# Memory usage: 936.77734375 MB
# iteration: 113
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5970008896656999 0.32700521026159596 0.007464185196622716 0.008419115498759865
# dt: 0.00748057346732952  max_vel: 0.7945892131585295  Seconds: 3512883710.421959   Days: 40658.37627803193 year 111.39281172063542
# Memory usage: 936.77734375 MB
# iteration: 114
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5956755155143165 0.3257807741708832 0.007451144159132316 0.008406976347322825
# dt: 0.007464185196622716  max_vel: 0.7962564127957799  Seconds: 3512883710.4294233   Days: 40658.376278118325 year 111.39281172087212
# Memory usage: 936.77734375 MB
# iteration: 115
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5936346024054446 0.32417753176655806 0.007443233336081383 0.008400572669694078
# dt: 0.007451144159132316  max_vel: 0.7979029895933849  Seconds: 3512883710.4368744   Days: 40658.37627820457 year 111.3928117211084
# Memory usage: 936.77734375 MB
# iteration: 116
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5911477364167813 0.322344342354738 0.007441576266067256 0.00840117696310816
# dt: 0.007443233336081383  max_vel: 0.7996838797176745  Seconds: 3512883710.444318   Days: 40658.376278290714 year 111.39281172134443
# Memory usage: 936.77734375 MB
# iteration: 117
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.588548359713121 0.3240617185197203 0.007446479800256791 0.0083903852138896
# dt: 0.007441576266067256  max_vel: 0.8014416161542943  Seconds: 3512883710.4517593   Days: 40658.37627837684 year 111.39281172158039
# Memory usage: 936.77734375 MB
# iteration: 118
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5942004241996501 0.3269151237600143 0.007437156726925459 0.008381206144501555
# dt: 0.007446479800256791  max_vel: 0.8031769548809101  Seconds: 3512883710.4592056   Days: 40658.37627846303 year 111.39281172181653
# Memory usage: 936.77734375 MB
# iteration: 119
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5971906828133201 0.32804510192655817 0.00742039182778249 0.008364938100755694
# dt: 0.007437156726925459  max_vel: 0.8048857301799481  Seconds: 3512883710.466643   Days: 40658.376278549105 year 111.39281172205234
# Memory usage: 936.77734375 MB
# iteration: 120
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5979435749826164 0.3282417573250968 0.007401799336587119 0.00834508149273177
# dt: 0.00742039182778249  max_vel: 0.8065685718372362  Seconds: 3512883710.4740634   Days: 40658.37627863499 year 111.39281172228765
# Memory usage: 936.77734375 MB
# iteration: 121
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5979102016709222 0.32775374566703463 0.007383335850404496 0.008326649498380509
# dt: 0.007401799336587119  max_vel: 0.8085938170560233  Seconds: 3512883710.4814653   Days: 40658.376278720665 year 111.39281172252237
# Memory usage: 936.77734375 MB
# iteration: 122
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5967700085252121 0.32663514001855326 0.0073677305656994815 0.008311560152557962
# dt: 0.007383335850404496  max_vel: 0.8105961540752789  Seconds: 3512883710.4888487   Days: 40658.37627880612 year 111.39281172275649
# Memory usage: 936.77734375 MB
# iteration: 123
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5948653020924355 0.3267811474177408 0.0073568604384728255 0.008293251698064087
# dt: 0.0073677305656994815  max_vel: 0.8125758102064171  Seconds: 3512883710.4962163   Days: 40658.376278891395 year 111.39281172299012
# Memory usage: 936.77734375 MB
# iteration: 124
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5962268062583306 0.32779364379241505 0.007342648309013982 0.008275894034822972
# dt: 0.0073568604384728255  max_vel: 0.8145334761043476  Seconds: 3512883710.503573   Days: 40658.37627897654 year 111.39281172322339
# Memory usage: 936.77734375 MB
# iteration: 125
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.59738014645086 0.3278755135379699 0.007325631687155326 0.008259493960910254
# dt: 0.007342648309013982  max_vel: 0.8164676369028743  Seconds: 3512883710.5109158   Days: 40658.37627906152 year 111.39281172345622
# Memory usage: 936.77734375 MB
# iteration: 126
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5968805072602469 0.32822272019086296 0.007309877683619169 0.008238608414247802
# dt: 0.007325631687155326  max_vel: 0.8183769412671559  Seconds: 3512883710.5182414   Days: 40658.376279146316 year 111.39281172368854
# Memory usage: 936.77734375 MB
# iteration: 127
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5979720711641868 0.32856364801648236 0.007291492599259176 0.008219184266461177
# dt: 0.007309877683619169  max_vel: 0.8202611154655186  Seconds: 3512883710.5255513   Days: 40658.37627923092 year 111.39281172392033
# Memory usage: 936.77734375 MB
# iteration: 128
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5979801774742274 0.328017573308578 0.007273134035950362 0.008201240099693417
# dt: 0.007291492599259176  max_vel: 0.8221188636091691  Seconds: 3512883710.5328426   Days: 40658.37627931531 year 111.39281172415153
# Memory usage: 936.77734375 MB
# iteration: 129
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5967401687819136 0.32679839837096963 0.007257834254618503 0.008186685687400096
# dt: 0.007273134035950362  max_vel: 0.8239670192162256  Seconds: 3512883710.540116   Days: 40658.37627939949 year 111.39281172438217
# Memory usage: 936.77734375 MB
# iteration: 130
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5947083333490156 0.3251595161655647 0.0072475087894840725 0.008177682816821281
# dt: 0.007257834254618503  max_vel: 0.8258018280964327  Seconds: 3512883710.547374   Days: 40658.37627948349 year 111.3928117246123
# Memory usage: 936.77734375 MB
# iteration: 131
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5932552410320301 0.3277551320724166 0.0072407398381660526 0.008153073547141851
# dt: 0.0072475087894840725  max_vel: 0.8276110044637808  Seconds: 3512883710.554621   Days: 40658.376279567376 year 111.39281172484212
# Memory usage: 936.77734375 MB
# iteration: 132
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5990048791545947 0.3303885891341457 0.0072200362970976355 0.0081324320828139
# dt: 0.0072407398381660526  max_vel: 0.8293947397150311  Seconds: 3512883710.561862   Days: 40658.37627965118 year 111.39281172507172
# Memory usage: 936.77734375 MB
# iteration: 133
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6015664846920975 0.33126449044403805 0.007193250157358856 0.008104886052004821
# dt: 0.0072200362970976355  max_vel: 0.8311488850533046  Seconds: 3512883710.5690823   Days: 40658.37627973475 year 111.39281172530069
# Memory usage: 936.77734375 MB
# iteration: 134
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6020260669328865 0.3309900135697549 0.00716546887892302 0.008076155924598066
# dt: 0.007193250157358856  max_vel: 0.8328713708447285  Seconds: 3512883710.5762753   Days: 40658.376279818 year 111.39281172552877
# Memory usage: 936.77734375 MB
# iteration: 135
# foward time taken: 0.002988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6011243082525413 0.32997812666930426 0.007139935121558776 0.008049892727566807
# dt: 0.00716546887892302  max_vel: 0.8345614274621582  Seconds: 3512883710.583441   Days: 40658.376279900935 year 111.39281172575599
# Memory usage: 936.77734375 MB
# iteration: 136
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5994548100726618 0.33158415176969475 0.007118450756578318 0.0080134221460221
# dt: 0.007139935121558776  max_vel: 0.8362190692875766  Seconds: 3512883710.590581   Days: 40658.376279983575 year 111.3928117259824
# Memory usage: 936.77734375 MB
# iteration: 137
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6034126773505578 0.3332000416066212 0.007087696434138225 0.007981545341139934
# dt: 0.007118450756578318  max_vel: 0.8378833502264207  Seconds: 3512883710.597699   Days: 40658.37628006596 year 111.39281172620811
# Memory usage: 936.77734375 MB
# iteration: 138
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6047422320535757 0.3333686395598558 0.007053969185837902 0.007946258140445084
# dt: 0.007087696434138225  max_vel: 0.8398440783707843  Seconds: 3512883710.604787   Days: 40658.376280148 year 111.39281172643287
# Memory usage: 936.77734375 MB
# iteration: 139
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6043507867484036 0.3325979164725015 0.007021311635127019 0.007912107199012478
# dt: 0.007053969185837902  max_vel: 0.8417779482584444  Seconds: 3512883710.6118407   Days: 40658.37628022963 year 111.39281172665653
# Memory usage: 936.77734375 MB
# iteration: 140
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6028536965125737 0.33130089389809086 0.00699227295011742 0.007881633519719846
# dt: 0.007021311635127019  max_vel: 0.8436847895314832  Seconds: 3512883710.618862   Days: 40658.376280310906 year 111.39281172687919
# Memory usage: 936.77734375 MB
# iteration: 141
# foward time taken: 0.003702 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6010346484926633 0.3303227720096841 0.006967564226634444 0.007853679597699854
# dt: 0.00699227295011742  max_vel: 0.8455651167443469  Seconds: 3512883710.6258545   Days: 40658.376280391836 year 111.39281172710092
# Memory usage: 936.77734375 MB
# iteration: 142
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5996730369563432 0.3290452643424399 0.0069460928722824096 0.007831994272424439
# dt: 0.006967564226634444  max_vel: 0.8474196021329143  Seconds: 3512883710.632822   Days: 40658.376280472476 year 111.39281172732186
# Memory usage: 936.77734375 MB
# iteration: 143
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5975885564779356 0.3273848934995104 0.0069295118325307424 0.007815762753855239
# dt: 0.0069460928722824096  max_vel: 0.849248584444666  Seconds: 3512883710.639768   Days: 40658.376280552875 year 111.39281172754212
# Memory usage: 936.77734375 MB
# iteration: 144
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5950562437824481 0.3254939905921001 0.006918844130645158 0.007806143940730912
# dt: 0.0069295118325307424  max_vel: 0.8510528025176195  Seconds: 3512883710.6466975   Days: 40658.37628063307 year 111.39281172776184
# Memory usage: 936.77734375 MB
# iteration: 145
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5922527536969131 0.32612580420154574 0.0069147206330062 0.0077911043957930165
# dt: 0.006918844130645158  max_vel: 0.8528332049019203  Seconds: 3512883710.6536164   Days: 40658.37628071315 year 111.39281172798123
# Memory usage: 936.77734375 MB
# iteration: 146
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5954103838237068 0.3277709541742339 0.006903254220579943 0.007778628937087711
# ...
# dt: 0.004204265436882167  max_vel: 1.315421888399596  Seconds: 3512883712.264461   Days: 40658.37629935719 year 111.39281177906079
# Memory usage: 936.76953125 MB
# iteration: 452
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5976361783418148 0.32693265934009863 0.0041827312212874045 0.004719061885022605
# dt: 0.00419280654503233  max_vel: 1.3165935703876874  Seconds: 3512883712.268654   Days: 40658.37629940572 year 111.39281177919375
# Memory usage: 936.76953125 MB
# iteration: 453
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5962768460593401 0.3267375979782382 0.004174580867801475 0.0047082839334751546
# dt: 0.0041827312212874045  max_vel: 1.3177250116768884  Seconds: 3512883712.2728367   Days: 40658.376299454125 year 111.39281177932637
# Memory usage: 936.76953125 MB
# iteration: 454
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5967163799071175 0.32737164028960475 0.004165832424446406 0.004697287875603996
# dt: 0.004174580867801475  max_vel: 1.3188155168951206  Seconds: 3512883712.2770114   Days: 40658.376299502444 year 111.39281177945875
# Memory usage: 936.76953125 MB
# iteration: 455
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5976682804514016 0.32733489625517037 0.004155777274904671 0.004687549253818038
# dt: 0.004165832424446406  max_vel: 1.3198636544524864  Seconds: 3512883712.281177   Days: 40658.37629955066 year 111.39281177959086
# Memory usage: 936.76953125 MB
# iteration: 456
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5971784564449841 0.326519969571858 0.004146426266205428 0.004678566683652748
# dt: 0.004155777274904671  max_vel: 1.3210111866716887  Seconds: 3512883712.2853327   Days: 40658.376299598756 year 111.39281177972262
# Memory usage: 936.76953125 MB
# iteration: 457
# foward time taken: 0.003962 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5957671705587425 0.3256349798681473 0.0041390544798777205 0.0046705738799793645
# dt: 0.004146426266205428  max_vel: 1.322298999991972  Seconds: 3512883712.2894793   Days: 40658.37629964675 year 111.3928117798541
# Memory usage: 936.76953125 MB
# iteration: 458
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5948552136002052 0.3256186314808284 0.004132961862379933 0.004662317044860777
# dt: 0.0041390544798777205  max_vel: 1.3236339620516326  Seconds: 3512883712.293618   Days: 40658.37629969465 year 111.39281177998535
# Memory usage: 936.76953125 MB
# iteration: 459
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5950837662274485 0.3252034776163188 0.004126561164034121 0.0046566422153118915
# dt: 0.004132961862379933  max_vel: 1.3252108042197008  Seconds: 3512883712.297751   Days: 40658.376299742486 year 111.3928117801164
# Memory usage: 936.76953125 MB
# iteration: 460
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.594141646586339 0.3241607687642299 0.004121476206330233 0.00465241776442421
# dt: 0.004126561164034121  max_vel: 1.3267612344980007  Seconds: 3512883712.3018775   Days: 40658.376299790245 year 111.39281178024724
# Memory usage: 936.76953125 MB
# iteration: 461
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5924554053207748 0.3242968463584086 0.004118738062168935 0.004646294796762834
# dt: 0.004121476206330233  max_vel: 1.328284939668173  Seconds: 3512883712.305999   Days: 40658.376299837946 year 111.39281178037794
# Memory usage: 936.76953125 MB
# iteration: 462
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5936021070097482 0.32459746775930315 0.004114410274636548 0.00464234761689245
# dt: 0.004118738062168935  max_vel: 1.32978193185686  Seconds: 3512883712.3101177   Days: 40658.37629988562 year 111.39281178050854
# Memory usage: 936.78515625 MB
# iteration: 463
# foward time taken: 0.003990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.593652401695368 0.3240923186974324 0.004110017390247887 0.004638914388931253
# dt: 0.004114410274636548  max_vel: 1.331250724009895  Seconds: 3512883712.3142323   Days: 40658.37629993325 year 111.39281178063904
# Memory usage: 936.78515625 MB
# iteration: 464
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5925999473153213 0.32299735688135467 0.00410708647634257 0.004637099077057443
# dt: 0.004110017390247887  max_vel: 1.3326903851352037  Seconds: 3512883712.318342   Days: 40658.37629998082 year 111.39281178076936
# Memory usage: 936.78515625 MB
# iteration: 465
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5908470951179705 0.32153448174089516 0.0041065899095563616 0.00463800108425285
# dt: 0.00410708647634257  max_vel: 1.3341004933597662  Seconds: 3512883712.322449   Days: 40658.37630002834 year 111.39281178089958
# Memory usage: 936.78515625 MB
# iteration: 466
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5886539162254081 0.3203355965558695 0.004109148510844398 0.004640906351086527
# dt: 0.0041065899095563616  max_vel: 1.3354808942086551  Seconds: 3512883712.3265557   Days: 40658.37630007588 year 111.3928117810298
# Memory usage: 936.78515625 MB
# iteration: 467
# foward time taken: 0.002987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5876305286922264 0.32150019220491727 0.0041131398583212535 0.004640428652163074
# dt: 0.004109148510844398  max_vel: 1.336831544883426  Seconds: 3512883712.330665   Days: 40658.37630012344 year 111.3928117811601
# Memory usage: 936.78515625 MB
# iteration: 468
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.590090180820138 0.3231176370837103 0.004113697083891063 0.004640276435565251
# dt: 0.0041131398583212535  max_vel: 1.3381670388653304  Seconds: 3512883712.3347783   Days: 40658.37630017105 year 111.39281178129053
# Memory usage: 936.78515625 MB
# iteration: 469
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.592593064101277 0.3261436216035133 0.0041107730955421366 0.004632261203751991
# dt: 0.004113697083891063  max_vel: 1.3395355627838967  Seconds: 3512883712.338892   Days: 40658.37630021865 year 111.39281178142097
# Memory usage: 936.78515625 MB
# iteration: 470
# foward time taken: 0.003004 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5972731722948658 0.32813126438258766 0.004101393259229509 0.0046233470252692475
# dt: 0.0041107730955421366  max_vel: 1.3408716250950083  Seconds: 3512883712.343003   Days: 40658.37630026624 year 111.39281178155133
# Memory usage: 936.78515625 MB
# iteration: 471
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5992022524995679 0.3286120729367599 0.004089396635022162 0.0046114469803360866
# dt: 0.004101393259229509  max_vel: 1.3421720907606856  Seconds: 3512883712.347104   Days: 40658.37630031371 year 111.39281178168139
# Memory usage: 936.78515625 MB
# iteration: 472
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5993321337781596 0.32811616544683053 0.004077258361554255 0.004599347453903549
# dt: 0.004089396635022162  max_vel: 1.34343520931855  Seconds: 3512883712.3511934   Days: 40658.37630036104 year 111.39281178181106
# Memory usage: 936.78515625 MB
# iteration: 473
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.598303401064289 0.3269991840143969 0.004066553096084946 0.0045888240700905645
# dt: 0.004077258361554255  max_vel: 1.3446600579950523  Seconds: 3512883712.355271   Days: 40658.37630040823 year 111.39281178194035
# Memory usage: 936.78515625 MB
# iteration: 474
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5965398944060983 0.3259373329686738 0.00405827112485084 0.004579753835990759
# dt: 0.004066553096084946  max_vel: 1.345846176954092  Seconds: 3512883712.3593373   Days: 40658.3763004553 year 111.3928117820693
# Memory usage: 936.78515625 MB
# iteration: 475
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.595403016666192 0.3256438708636611 0.0040515514778197625 0.0045712501304909685
# dt: 0.00405827112485084  max_vel: 1.3469933330882287  Seconds: 3512883712.3633957   Days: 40658.37630050226 year 111.39281178219798
# Memory usage: 936.78515625 MB
# iteration: 476
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5952048713890833 0.32499289209639687 0.004045112229047987 0.00456550789579063
# dt: 0.0040515514778197625  max_vel: 1.348100956944847  Seconds: 3512883712.3674474   Days: 40658.37630054916 year 111.39281178232646
# Memory usage: 936.78515625 MB
# iteration: 477
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5939864154362337 0.32379778132005904 0.0040403387824544225 0.004561611670296608
# dt: 0.004045112229047987  max_vel: 1.349168063476344  Seconds: 3512883712.3714924   Days: 40658.37630059598 year 111.39281178245473
# Memory usage: 936.78515625 MB
# iteration: 478
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5921218500100549 0.3222649024754539 0.004038109340278209 0.004560554917123388
# dt: 0.0040403387824544225  max_vel: 1.3501940001860349  Seconds: 3512883712.3755326   Days: 40658.37630064274 year 111.39281178258285
# Memory usage: 936.78515625 MB
# iteration: 479
# foward time taken: 0.003988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5898528895586641 0.3224724804214143 0.004038981290166934 0.004557451462010661
# dt: 0.004038109340278209  max_vel: 1.3511782511470174  Seconds: 3512883712.379571   Days: 40658.37630068948 year 111.39281178271091
# Memory usage: 936.78515625 MB
# iteration: 480
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5915725499414365 0.32436618444497206 0.004037501977784397 0.004553100498397153
# dt: 0.004038981290166934  max_vel: 1.3522101773698834  Seconds: 3512883712.38361   Days: 40658.37630073622 year 111.39281178283896
# Memory usage: 936.78515625 MB
# iteration: 481
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5944607057875252 0.32543702234740807 0.004032093802466035 0.00454843367253495
# dt: 0.004037501977784397  max_vel: 1.3532967593584286  Seconds: 3512883712.387647   Days: 40658.376300782955 year 111.392811782967
# Memory usage: 936.78515625 MB
# iteration: 482
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5953217110395853 0.3253604109874983 0.0040255274472813535 0.0045425550049849025
# dt: 0.004032093802466035  max_vel: 1.3543423744338814  Seconds: 3512883712.3916793   Days: 40658.37630082962 year 111.39281178309486
# Memory usage: 936.78515625 MB
# iteration: 483
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5947873376775302 0.32465186881941516 0.004019693677210516 0.004537135193156541
# dt: 0.0040255274472813535  max_vel: 1.3555887415401777  Seconds: 3512883712.3957047   Days: 40658.37630087621 year 111.3928117832225
# Memory usage: 936.78515625 MB
# iteration: 484
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5938314237555388 0.3247948605322069 0.004015159786648924 0.004530161015989324
# dt: 0.004019693677210516  max_vel: 1.3568225117091826  Seconds: 3512883712.3997245   Days: 40658.37630092273 year 111.39281178334996
# Memory usage: 936.78515625 MB
# iteration: 485
# foward time taken: 0.002988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.594379179945051 0.32455357821683145 0.004009891529735621 0.004525723969666892
# dt: 0.004015159786648924  max_vel: 1.3580259652707753  Seconds: 3512883712.4037395   Days: 40658.376300969205 year 111.39281178347727
# Memory usage: 936.78515625 MB
# iteration: 486
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5936478350866341 0.3236254643617338 0.0040056164007711784 0.004522375263361416
# dt: 0.004009891529735621  max_vel: 1.3591979764289146  Seconds: 3512883712.407749   Days: 40658.37630101562 year 111.39281178360443
# Memory usage: 936.78515625 MB
# iteration: 487
# foward time taken: 0.003985 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5921012440167279 0.32226653583860304 0.004003433982756328 0.004521357252105749
# dt: 0.0040056164007711784  max_vel: 1.360337908466195  Seconds: 3512883712.4117546   Days: 40658.37630106197 year 111.39281178373143
# Memory usage: 936.78515625 MB
# iteration: 488
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.590040895649137 0.3209452559115753 0.004004043232888923 0.004522608437792255
# dt: 0.004003433982756328  max_vel: 1.3614453724834084  Seconds: 3512883712.415758   Days: 40658.376301108314 year 111.39281178385839
# Memory usage: 936.78515625 MB
# iteration: 489
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.588333079700887 0.31974875636505273 0.004006974825640394 0.004526676875601304
# dt: 0.004004043232888923  max_vel: 1.362825113324524  Seconds: 3512883712.419762   Days: 40658.376301154654 year 111.39281178398535
# Memory usage: 936.78515625 MB
# iteration: 490
# foward time taken: 0.002988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5866086085447014 0.32063680909292824 0.004012263407383373 0.004527479033453861
# dt: 0.004006974825640394  max_vel: 1.364393845739478  Seconds: 3512883712.423769   Days: 40658.37630120103 year 111.39281178411241
# Memory usage: 936.78515625 MB
# iteration: 491
# foward time taken: 0.002988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5893110931413759 0.32212978112116736 0.004013867417373838 0.0045292445550735765
# dt: 0.004012263407383373  max_vel: 1.3659396525301493  Seconds: 3512883712.427781   Days: 40658.37630124747 year 111.39281178423964
# Memory usage: 936.78515625 MB
# iteration: 492
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5910539080576822 0.3229784456721871 0.004013101221112645 0.004528671557396956
# dt: 0.004013867417373838  max_vel: 1.367460126949073  Seconds: 3512883712.431795   Days: 40658.37630129392 year 111.39281178436691
# Memory usage: 936.78515625 MB
# iteration: 493
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5919374826055546 0.3229175958753049 0.004011136627013011 0.0045279777204740934
# dt: 0.004013101221112645  max_vel: 1.3689534183775403  Seconds: 3512883712.435808   Days: 40658.37630134037 year 111.39281178449417
# Memory usage: 936.78515625 MB
# iteration: 494
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5914063754645393 0.3220958234457991 0.0040098928164473985 0.004528068059078836
# dt: 0.004011136627013011  max_vel: 1.3704181435835443  Seconds: 3512883712.4398193   Days: 40658.376301386794 year 111.39281178462136
# Memory usage: 936.78515625 MB
# iteration: 495
# foward time taken: 0.002988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5899707662959983 0.3207945965340772 0.004010598390022359 0.00453033027673434
# dt: 0.0040098928164473985  max_vel: 1.3718536211671981  Seconds: 3512883712.443829   Days: 40658.37630143321 year 111.39281178474852
# Memory usage: 936.78515625 MB
# iteration: 496
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5879624786652593 0.3232249478469793 0.004014040612174751 0.004524292864996214
# dt: 0.004010598390022359  max_vel: 1.3732595602056896  Seconds: 3512883712.4478397   Days: 40658.37630147963 year 111.39281178487569
# Memory usage: 936.78515625 MB
# iteration: 497
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5939249021450008 0.32653936497060126 0.004009386877673691 0.004518946116079311
# dt: 0.004014040612174751  max_vel: 1.3746358593375754  Seconds: 3512883712.4518538   Days: 40658.376301526085 year 111.39281178500298
# Memory usage: 936.78515625 MB
# iteration: 498
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.597880811351926 0.32812380662449847 0.00399942494501338 0.004509339417447016
# dt: 0.004009386877673691  max_vel: 1.3759786369243199  Seconds: 3512883712.455863   Days: 40658.37630157249 year 111.3928117851301
# Memory usage: 936.78515625 MB
# iteration: 499
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5993332894880659 0.32862712722388 0.003987552190434363 0.004496756575711286
# dt: 0.00399942494501338  max_vel: 1.3772851615890878  Seconds: 3512883712.459862   Days: 40658.37630161878 year 111.39281178525694
# Memory usage: 936.78515625 MB
# 26

# %%
# Check all member variables for class sim0
print(dir(sim0))
# Out:
# ['A0', 'A1d', 'A1s', 'A2d', 'A2s', 'Batch_size', 'Bd', 'Bs', 'Cs', 'GetTtstress', 'Init_condition', 'Init_condition1', 'InputHetoparamter', 'Para0', 'Relerrormax1_last', 'Relerrormax2_last', 'RungeKutte_solve_Dormand_Prince', 'RungeKutte_solve_Dormand_Prince_gpu', 'T_globalarr', 'Tno', 'Tt', 'Tt1o', 'Tt2o', 'V0', 'Vpl_con', 'Vpld', 'Vpls', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'a', 'arriT', 'ave_elesize', 'b', 'calc_corefunc', 'calc_nucleaszie_cohesivezone', 'dc', 'density', 'derivative', 'derivative_gpu', 'dirname', 'eleVec', 'elelst', 'f0', 'fix_Tn', 'fric', 'get_coreAB', 'get_coreAB_mulproess', 'get_coreAB_mulproess1', 'get_coreAB_mulproess1_', 'get_coreAB_mulproess2', 'get_coreAB_mulproess2_', 'get_rotation1', 'get_value', 'hRA', 'halfspace_jud', 'htry', 'initGPUvariable', 'lambda_', 'localTra', 'maxsize', 'maxslipv0', 'maxslipvque', 'mu', 'nodelst', 'normal_loading', 'num_process', 'ouputVTK', 'outputtxt', 'rake', 'rake0', 'randompatch', 'read_parameter', 'shear_loading', 'shear_loadingD', 'shear_loadingS', 'simu_forward', 'simu_forwardGPU', 'slip', 'slip1', 'slip2', 'slipv', 'slipv1', 'slipv2', 'slipvC', 'state', 'time', 'useGPU', 'val_nv', 'vec_Tra', 'worker', 'worker1', 'worker2', 'xg']

# %% [markdown]
# ## Step 6: Visualize Results
#
# The simulation generates VTK files, visualize them using PyVista.You can also output all results in your own format by accessing the member variables of sim0(e.g. sim0.slip).

# %%
import pyvista as pv
import glob
import os

# set vtk file path
folder_path = "../outvtk/"  

vtk_files = glob.glob(os.path.join(folder_path, "*.vtk")) + glob.glob(os.path.join(folder_path, "*.vtu"))


#read state file for time show
def is_number(s):
    try:
        float(s) 
        return True
    except ValueError:
        return False

def readstate(fname):
    f=open(fname,'r')
    K=0
    data0=[]
    for line in f:
        tem=line.split()
        
        if(len(tem)==6 and is_number(tem[0])==True):
            data0.append(np.array(tem).astype(float))
    return np.array(data0)
state=readstate('state.txt')
print(state.shape)

# # show one figure 
plotter = pv.Plotter(off_screen=True)
mesh = pv.read(vtk_files[10])
plotter.add_mesh(mesh, scalars='Shear_[MPa]', cmap="viridis", show_edges=False)  # show shear stress

#plotter.camera_position = [(0, -5, 0), (0, 0, 0), (0, 0, 1)]
plotter.show()

# create animation
outsteps=int(sim0.Para0['outsteps'])
plotter = pv.Plotter(off_screen=True)
plotter.open_gif('animation.gif')  # Initialize GIF output

for i, vtk_file in enumerate(vtk_files):
    mesh = pv.read(folder_path+'step'+str(i*outsteps)+'.vtk')
    plotter.clear()  # Clear previous mesh
    plotter.add_mesh(
        mesh,
        scalars='Shear_[MPa]',  #output shear stress, many variables such as (slip, slipv) can be used.
        cmap="viridis",
        show_edges=False,
    )
    timeyear=state[i*outsteps,-1]/365
    plotter.add_text(f"Time: {timeyear}", position="upper_left", font_size=14, color="white", shadow=True)
    plotter.write_frame()  # Write frame to GIF

plotter.close()
print('Video has been saved in src folder.')
# Out:
# (502, 6)
# D:\Anaconda3\envs\testquake\Lib\site-packages\pyvista\jupyter\notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# Video has been saved in src folder.

# %% [markdown]
# ## GPU acceleration
# Install cupy if you want to use GPU acceleration, we recommened to use conda in prompt terminal (e.g. CUDA 11.8):conda install -c conda-forge cupy cudatoolkit=11.8
#
# **Notes**:
# CuPy relies on NVIDIA CUDA for GPU computing, so the following components are required:
#
# 1. **NVIDIA GPU Driver**:
# Ensure your system has a CUDA-capable NVIDIA GPU (check compatibility at https://developer.nvidia.com/cuda-gpus).
# The driver version must support the CUDA Toolkit version used by CuPy (e.g., CUDA 10.2–12.x for CuPy v13.x).
#
# 2. **CUDA Toolkit**:
# CuPy supports specific CUDA versions (check the latest compatibility at https://docs.cupy.dev/en/stable/install.html).
# Common versions: CUDA 11.8 or 12.2 are widely used.

# %%
import cupy as cp
print(cp.cuda.is_available())  # check CUDA availble
print(cp.cuda.runtime.getDeviceCount())
# Out:
# True
# 1

# %% [markdown]
# The GPU operates in a similar way to the CPU, only the output is converted to numpy each time.
#
# **Note**: Make sure to set GPU:True in the parameter.txt

# %%
start_time=time.time()
    
totaloutputsteps=int(sim0.Para0['totaloutputsteps'])
directory='../outvtk'
if not os.path.exists(directory):
    os.mkdir(directory)

f=open('state.txt','w')
f.write('iteration time_step(s) maximum_slip1_rate(m/s) maximum_slip2_rate(m/s) time(s) time(h)\n')


if(sim0.useGPU==True): #GPU case
    sim0.initGPUvariable()
    
    for i in range(totaloutputsteps):
        print('iteration:',i)
        if(i==0):
            dttry=sim0.htry
        else:
            dttry=dtnext
        dttry,dtnext=sim0.simu_forwardGPU(dttry)
        # transform from cupy to numpy variables
        sim0.slipv1=sim0.slipv1_gpu.get()
        sim0.slipv2=sim0.slipv2_gpu.get()
        sim0.slipv=sim0.slipv_gpu.get()
        sim0.slip=sim0.slip_gpu.get()
        sim0.Tt1o=sim0.Tt1o_gpu.get()
        sim0.Tt2o=sim0.Tt2o_gpu.get()
        sim0.Tt=sim0.Tt_gpu.get()
        #sim0.state1=sim0.state1_gpu.get()
        #sim0.state2=sim0.state2_gpu.get()
        sim0.rake=sim0.rake_gpu.get()
        year=sim0.time/3600/24/365

        print('dt:',dttry,' Seconds:',sim0.time,'  Days:',sim0.time/3600/24,'year',year)
        print(' max_vel1:',np.max(np.abs(sim0.slipv1)),' max_vel2:',np.max(np.abs(sim0.slipv2)),' min_Tt1:',np.min(sim0.Tt1o),' min_Tt2:',np.min(sim0.Tt2o))  
        f.write('%d %f %.16e %.16e %f %f\n' %(i,dttry,np.max(np.abs(sim0.slipv1)),np.max(np.abs(sim0.slipv2)),sim0.time,sim0.time/3600.0/24.0))

        memory_info = process.memory_info()
        print(f"Memory usage: {memory_info.rss / (1024 ** 2)} MB")

        if(sim0.Para0['outputvtk']=='True'):
            outsteps=int(sim0.Para0['outsteps'])#output steps
            if(i%outsteps==0):
                fname=directory+'/step'+str(i)+'.vtk'
                sim0.ouputVTK(fname)

# %% [markdown]
# ## For MPI version on Linux system
#
# ## Step 1: Set Up Conda environment
# 1. Download latest Miniconda3
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O miniconda.sh
#
# 2. Install Miniconda with the following command:
# bash miniconda.sh -b -u -p ~/miniconda3
#
# Parameters:
#
# -b: Batch mode, automatically accepts the license agreement.
# -u: Updates the installation if the directory already exists.
# -p ~/miniconda3: Specifies the installation directory (here, miniconda3 in the home directory).
#
# 4. After installation, initialize Conda for terminal use:
# ~/miniconda3/bin/conda init
#
# 5. Close and reopen the terminal, or run:
# source ~/.bashrc
#
# 6. Verify the Installation,Check the Conda version:
# conda --version
#
# 7. After installation, create a new environment:
# conda create -n PyQuake3D python=3.12
#
# 8. Activate the environment:
# conda activate PyQuake3D
#
#
# **Notes**:Dependencies: Ensure wget is installed. If not, install it:
# bashsudo apt install wget  # For Ubuntu/Debian
# sudo yum install wget  # For CentOS/RHEL

# %% [markdown]
# ## Step 2: Install Python and C++ Dependencies
#
# **For MPI-CPU verison in Linux (e.g. ubantu)**
# 1. Download from https://github.com/Computational-Geophysics/PyQuake3D
# 2. Install an MPI implementation and g++ compiler(including gcc and other related tools). Common options are:
# - sudo apt update
# - sudo apt install g++
# - sudo apt install openmpi-bin libopenmpi-dev
#
# 3. Install PyQuake3D using pip: pip install -r requirements (make sure PyQuake3D environment is activated).
# 4. Navigate to the src directory, run make to build TDstressFS_C.so.The generated library is called by the Python script Hmatrix.py via dynamic loading (e.g., using ctypes).
#
# **Notes1**:MPI-CPU version is recommended for use on Linux because it requires compiling a C dynamic library, which used for green's function calculation acceleration. Compiling C dynamic libraries (DLLs) on Windows can be less convenient compared to Linux or other Unix-like systems for several reasons, stemming from differences in tooling, ecosystem, and system design.
#
# **Notes2**:PyQuake3D supports Python 3.8 and above, so there is no need to specify a specific version when installing the library in the requirement.txt.

# %% [markdown]
# ## Step 3: Explore Examples for MPI-based PyQuake3D
#
#
# To execute benchmarks like BP5-QD, use:
# ```bash
# In the PyQuake3D_MPI_V2 directory, To run the BP5-QD benchmark:
# mpirun -np 10 python src/main.py -g examples/BP5-QD/bp5t.msh -p examples/BP5-QD/parameter.txt
# Ensure you modify the input parameter (`parameter.txt`) as follows:
# - `Corefunc directory`: `bp5t_core`
# - `InputHetoparamter`: `True`
# - `Inputparamter file`: `bp5tparam.dat`
#
# To run the **HF-model**:
# mpirun -np 10 python src/main.py -g examples/HF-model/HFmodel.msh -p examples/HF-model/parameter.txt
#
# To run the  **EAFZ-model**:
# mpirun -np 10 python src/main.py -g examples/EAFZ-model/turkey.msh -p examples/EAFZ-model/parameter.txt
#
# To run the  **Lab-model**:
# mpirun -np 10 python src/main.py -g examples/Lab-model/lab.msh -p examples/Lab-model/parameter.txt
#
#
#
# Run these in a Linux terminal.

# %% [markdown]
# ## Additional Notes
#
# - **Performance:** Use more CPUs (`-np`) or multithreaded parallelism in parameter.txt.
# - **Help:** Contact authors at rongjiang@csj.uestc.edu.cn or luca.dalzilio@ntu.edu.sg.
# - **Manual:** Refer to the Code Manual PDF for detailed parameter info.
#
# Save this notebook and run cells sequentially. For advanced usage, explore `src/` or modify parameters for custom simulations.
