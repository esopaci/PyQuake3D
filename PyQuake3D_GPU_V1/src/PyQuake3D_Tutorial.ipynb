# %% [markdown]
# ## PyQuake3D Usage Tutorial
#
# This Jupyter Notebook provides a step-by-step guide to installing and using **PyQuake3D**, a Python-based Boundary Element Method (BEM) tool for 3D earthquake sequence simulations with seismic and aseismic slip. We'll cover installation, compilation, setup, and running a simple simulation.
#
# **Features:**
# - 3D non-planar quasi-dynamic earthquake cycle simulations
# - Support for rate-and-state aging friction laws
# - Support for Hierarchical matrix storage and calculation
# - Support for GPU acceleration via CuPy
# - MPI acceleration support
# - Suitable for large model earthquake cycle simulation
#
# **Note:** MPI simulations may not run seamlessly in Jupyter due to their multi-process nature. We will first show how to install the simplest single-CPU version using conda on Windows, then how to install the GPU driver and cupy, finally how to run MPI-accelerated PyQuake3D on Linux system.

# %% [markdown]
# ## Step 1: Set Up Conda environment
#
# 1. Download from https://www.anaconda.com/docs/getting-started/miniconda/install
# 2. Then install it using exe program.
# 3. Open miniconda Prompt and navigate to the working directory(e.g. E:\work) using:
# E:
# then
# cd E:\work
#
# 3. After installation, create a new environment:
# conda create -n PyQuake3D python=3.12
# 4. Activate the environment:
# conda activate PyQuake3D
# 5. Install Jupyter notebook using: conda install jupyter notebook, then you can open the PyQuake3D_Tutorial.ipynb

# %% [markdown]
# ## Step 2: Install Python Dependencies
#
# **For single GPU/CPU verison**
# 1. Download from https://github.com/Computational-Geophysics/PyQuake3D
#
# 2. Install PyQuake3D using pip: pip install -r dependences.txt (make sure PyQuake3D environment is activated)
#
# **Notes**:PyQuake3D supports Python 3.8 and above, so there is no need to specify a specific version when installing the library.

# %% [markdown]
# ## Step 3: Runging a simple case (For single GPU/CPU verison).
# The easiest way to run pyquake3d is to run the single CPU version of Pyquake3D, without installing cupy.
# 1. Setup mesh model using Gmesh.
# 2. Setup parameter.txt.
# 3. Read model and mesh parameter(Please refer to mannul for specific meanning).
# 4. Calculating Green functions.
# 5. Calculating Qusi-Dynamic model.
# 6. Export results.
# The msh model and parameter.txt have been prepared at folder bp5t_3k

# %%
#Let runing PyQuake3D
#First Import all sub-functions

import readmsh
import numpy as np
import sys
import matplotlib.pyplot as plt
import QDsim
from math import *
import time
import argparse
import os
import psutil
from datetime import datetime
process = psutil.Process(os.getpid())

# %%
#Second,read the model file, parameter file, and create a basic class, then it start to calculate greenfunctions

fnamegeo='../bp5t_3k/bp5t.msh'
fnamePara='../bp5t_3k/parameter.txt'
nodelst,elelst=readmsh.read_mshV2(fnamegeo)
sim0=QDsim.QDsim(elelst,nodelst,fnamePara)
# Out:
# Cs 3464.0
# First Lamé constants 32038120320.0
# Shear Modulus 32038120320.0
# Youngs Modulus 80095300800.0
# Poissons ratio 0.25
# [40. 40. 40. ... 40. 40. 40.]
# L: 0.1
# maximum element size 1249.392905015399
# average elesize 1009.2986930015212
# Critical nucleation size 9436.005321762927
# Cohesive zone: 2359.0013304407316
# Start to load core functions...
# Core functions load completed.

# %% [markdown]
# **Note**
# 1. The Green function calculation is saved in the Corefunc directory defined in parameter.txt. The next time you start the program, you no longer need to calculate the Green function.
# 2. msh files are generated by *Gmesh*, link https://gmsh.info/. For convenience, We have created a simple 3D vertical plane geometry for simulating earthquake cycles on a strike-slip fault (bp5t.msh), and have set appropriate parameters (stress, friction parameters, etc).
# 3. Make sure to export version 2 of mesh file if you create your model.

# %%
#Third Calculating Qusi-Dynamic model

start_time=time.time()
    
totaloutputsteps=int(sim0.Para0['totaloutputsteps']) # The total time step of the simulation
directory='../outvtk'
if not os.path.exists(directory):  # The output directory
    os.mkdir(directory)

# Outputs the state of the system (including sliding velocity, time step, etc.) to track the state of the simulation, 
# and more importantly, to record the time and step.
f=open('state.txt','w')  
f.write('iteration time_step(s) maximum_slip1_rate(m/s) maximum_slip2_rate(m/s) time(s) time(h)\n')


if(sim0.useGPU==False):  #CPU case make sure to set GPU:True in parameter.txt
    for i in range(totaloutputsteps): 
        print('iteration:',i)

        #update adaptive time step
        if(i==0):
            dttry=sim0.htry
        else:
            dttry=dtnext

        # Qusi-Dynamic model update
        dttry,dtnext=sim0.simu_forward(dttry)
        year=sim0.time/3600/24/365
        print('dt:',dttry,' max_vel:',np.max(np.abs(sim0.slipv)),' Seconds:',sim0.time,'  Days:',sim0.time/3600/24,
            'year',year)
        f.write('%d %f %.16e %.16e %f %f\n' %(i,dttry,np.max(np.abs(sim0.slipv1)),np.max(np.abs(sim0.slipv2)),sim0.time,sim0.time/3600.0/24.0))

        # Get the memory info
        memory_info = process.memory_info()
        print(f"Memory usage: {memory_info.rss / (1024 ** 2)} MB")

        # Output vtk files for virualization
        if(sim0.Para0['outputvtk']=='True'):
            outsteps=int(sim0.Para0['outsteps']) #output steps
            if(i%outsteps==0):
                fname=directory+'/step'+str(i)+'.vtk'
                sim0.ouputVTK(fname)

end_time = time.time()
timetake=end_time-start_time
f.write('Program end time: %s\n'%str(datetime.now()))
f.write("Time taken: %.2f seconds\n"%timetake)
# Out:
# iteration: 0
# foward time taken: 0.006977 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.000006561689076e-06 0.014264038732150024 0.014264020012986297
# dt: 0.001  max_vel: 1.0000000000000073e-09  Seconds: 0.001   Days: 1.1574074074074074e-08 year 3.1709791983764586e-11
# Memory usage: 717.87890625 MB
# iteration: 1
# foward time taken: 0.003990 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 0.021396058098225035 0.021396058098225035
# dt: 0.0015  max_vel: 1.0000000000000073e-09  Seconds: 0.0025   Days: 2.8935185185185185e-08 year 7.927447995941146e-11
# Memory usage: 718.234375 MB
# iteration: 2
# foward time taken: 0.004984 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 0.03209408714733756 0.03209408714733756
# dt: 0.0022500000000000003  max_vel: 1.0000000000000073e-09  Seconds: 0.004750000000000001   Days: 5.497685185185186e-08 year 1.506215119228818e-10
# Memory usage: 718.234375 MB
# iteration: 3
# foward time taken: 0.003990 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 0.04814113072100633 0.04814113072100633
# dt: 0.0033750000000000004  max_vel: 1.0000000000000073e-09  Seconds: 0.008125   Days: 9.403935185185185e-08 year 2.5764205986808726e-10
# Memory usage: 718.234375 MB
# iteration: 4
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 0.07221169608150951 0.07221169608150951
# dt: 0.005062500000000001  max_vel: 1.0000000000000073e-09  Seconds: 0.013187500000000001   Days: 1.5263310185185186e-07 year 4.1817288178589553e-10
# Memory usage: 718.234375 MB
# iteration: 5
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 0.10831754412226427 0.10831754412226427
# dt: 0.0075937500000000015  max_vel: 1.0000000000000073e-09  Seconds: 0.02078125   Days: 2.405237268518519e-07 year 6.589691146626079e-10
# Memory usage: 718.234375 MB
# iteration: 6
# foward time taken: 0.004987 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 0.1624763161833964 0.1624763161833964
# dt: 0.011390625000000001  max_vel: 1.0000000000000073e-09  Seconds: 0.032171875   Days: 3.7235966435185185e-07 year 1.0201634639776763e-09
# Memory usage: 718.234375 MB
# iteration: 7
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 0.24371447427509457 0.24371447427509457
# dt: 0.017085937500000002  max_vel: 1.0000000000000073e-09  Seconds: 0.049257812500000005   Days: 5.701135706018519e-07 year 1.5619549879502792e-09
# Memory usage: 718.234375 MB
# iteration: 8
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 0.36557171141264183 0.36557171141264183
# dt: 0.025628906250000003  max_vel: 1.0000000000000073e-09  Seconds: 0.07488671875000001   Days: 8.66744429976852e-07 year 2.3746422739091836e-09
# Memory usage: 718.234375 MB
# iteration: 9
# foward time taken: 0.004984 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 0.5483575671189628 0.5483575671189628
# dt: 0.03844335937500001  max_vel: 1.0000000000000073e-09  Seconds: 0.11333007812500001   Days: 1.3116907190393519e-06 year 3.5936732028475393e-09
# Memory usage: 718.234375 MB
# iteration: 10
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 0.8225363506784442 0.8225363506784442
# dt: 0.057665039062500006  max_vel: 1.0000000000000073e-09  Seconds: 0.17099511718750002   Days: 1.9791101526331023e-06 year 5.422219596255075e-09
# Memory usage: 718.234375 MB
# iteration: 11
# foward time taken: 0.004986 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 1.2338045260176662 1.2338045260176662
# dt: 0.08649755859375001  max_vel: 1.0000000000000073e-09  Seconds: 0.25749267578125   Days: 2.980239303023727e-06 year 8.165039186366374e-09
# Memory usage: 718.234375 MB
# iteration: 12
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 1.8507067890264992 1.8507067890264992
# dt: 0.129746337890625  max_vel: 1.0000000000000073e-09  Seconds: 0.387239013671875   Days: 4.481933028609665e-06 year 1.2279268571533329e-08
# Memory usage: 718.234375 MB
# iteration: 13
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 2.776060183539749 2.776060183539749
# dt: 0.1946195068359375  max_vel: 1.0000000000000073e-09  Seconds: 0.5818585205078125   Days: 6.734473616988571e-06 year 1.8450612649283755e-08
# Memory usage: 718.234375 MB
# iteration: 14
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 4.164090275309623 4.164090275309623
# dt: 0.29192926025390625  max_vel: 1.0000000000000073e-09  Seconds: 0.8737877807617187   Days: 1.011328449955693e-05 year 2.77076287659094e-08
# Memory usage: 718.23828125 MB
# iteration: 15
# foward time taken: 0.005982 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 6.246135412964434 6.246135412964434
# dt: 0.43789389038085935  max_vel: 1.0000000000000073e-09  Seconds: 1.311681671142578   Days: 1.5181500823409468e-05 year 4.159315294084786e-08
# Memory usage: 718.23828125 MB
# iteration: 16
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 9.369203119446652 9.369203119446652
# dt: 0.656840835571289  max_vel: 1.0000000000000073e-09  Seconds: 1.968522506713867   Days: 2.2783825309188275e-05 year 6.242143920325555e-08
# Memory usage: 718.23828125 MB
# iteration: 17
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 14.053804679169977 14.053804679169977
# dt: 0.9852612533569336  max_vel: 1.0000000000000073e-09  Seconds: 2.9537837600708006   Days: 3.418731203785649e-05 year 9.36638685968671e-08
# Memory usage: 718.23828125 MB
# iteration: 18
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 21.080707018754968 21.080707018754968
# dt: 1.4778918800354004  max_vel: 1.0000000000000073e-09  Seconds: 4.431675640106201   Days: 5.129254213085882e-05 year 1.4052751268728444e-07
# Memory usage: 718.23828125 MB
# iteration: 19
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 31.62106052813245 31.62106052813245
# dt: 2.2168378200531005  max_vel: 1.0000000000000073e-09  Seconds: 6.648513460159302   Days: 7.695038727036229e-05 year 2.1082297882291038e-07
# Memory usage: 718.30859375 MB
# iteration: 20
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 47.43159079219867 47.43159079219867
# dt: 3.3252567300796505  max_vel: 1.0000000000000073e-09  Seconds: 9.973770190238952   Days: 0.00011543715497961749 year 3.162661780263493e-07
# Memory usage: 718.30859375 MB
# iteration: 21
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 71.147386188298 71.147386188298
# dt: 4.987885095119475  max_vel: 1.0000000000000073e-09  Seconds: 14.961655285358427   Days: 0.0001731673065435003 year 4.7443097683150767e-07
# Memory usage: 718.34765625 MB
# iteration: 22
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 106.72107928244701 106.72107928244701
# dt: 7.481827642679213  max_vel: 1.0000000000000073e-09  Seconds: 22.44348292803764   Days: 0.00025976253388932454 year 7.116781750392453e-07
# Memory usage: 718.34765625 MB
# iteration: 23
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 160.08161892367048 160.08161892367048
# dt: 11.222741464018819  max_vel: 1.0000000000000073e-09  Seconds: 33.666224392056456   Days: 0.00038965537490806085 year 1.0675489723508516e-06
# Memory usage: 718.34765625 MB
# iteration: 24
# foward time taken: 0.002995 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 240.12242838550574 240.12242838550574
# dt: 16.83411219602823  max_vel: 1.0000000000000073e-09  Seconds: 50.500336588084686   Days: 0.0005844946364361653 year 1.6013551683182612e-06
# Memory usage: 718.37890625 MB
# iteration: 25
# foward time taken: 0.002995 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 360.1836425782586 360.1836425782586
# dt: 25.251168294042344  max_vel: 1.0000000000000073e-09  Seconds: 75.75150488212702   Days: 0.0008767535287283221 year 2.4020644622693754e-06
# Memory usage: 718.37890625 MB
# iteration: 26
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 540.2754638673879 540.2754638673879
# dt: 37.876752441063516  max_vel: 1.0000000000000073e-09  Seconds: 113.62825732319054   Days: 0.0013151418671665572 year 3.603128403196047e-06
# Memory usage: 718.37890625 MB
# iteration: 27
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1e-06 810.4131958010819 810.4131958010819
# dt: 56.815128661595274  max_vel: 1.0000000000000073e-09  Seconds: 170.4433859847858   Days: 0.0019727243748239097 year 5.404724314586054e-06
# Memory usage: 718.37890625 MB
# iteration: 28
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000018179616641e-06 1215.619793701623 1215.6193517120685
# dt: 85.22269299239291  max_vel: 1.0000000000000073e-09  Seconds: 255.6660789771787   Days: 0.002959098136309939 year 8.107118181671066e-06
# Memory usage: 718.39453125 MB
# iteration: 29
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000017254686919e-06 1823.429690552434 1823.429061298917
# dt: 127.83403948858935  max_vel: 1.0000000000000073e-09  Seconds: 383.5001184657681   Days: 0.004438658778538982 year 1.2160708982298582e-05
# Memory usage: 718.3984375 MB
# iteration: 30
# foward time taken: 0.005980 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000017512190608e-06 2735.144535828651 2735.143577862209
# dt: 191.75105923288402  max_vel: 1.0000000000000073e-09  Seconds: 575.2511776986521   Days: 0.006657999741882547 year 1.8241095183239854e-05
# Memory usage: 718.3984375 MB
# iteration: 31
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000019690135682e-06 4102.7168037429765 4102.715188083875
# dt: 287.626588849326  max_vel: 1.0000000000000073e-09  Seconds: 862.8777665479781   Days: 0.009987011186897895 year 2.736167448465177e-05
# Memory usage: 718.3984375 MB
# iteration: 32
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.000001677962386e-06 6154.075205614464 6154.073140355201
# dt: 431.43988327398904  max_vel: 1.0000000000000073e-09  Seconds: 1294.3176498219673   Days: 0.014980528354420918 year 4.1042543436769635e-05
# Memory usage: 718.3984375 MB
# iteration: 33
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000018579203521e-06 9231.112808421698 9231.10937829105
# dt: 647.1598249109836  max_vel: 1.0000000000000073e-09  Seconds: 1941.477474732951   Days: 0.022470804105705452 year 6.156384686494645e-05
# Memory usage: 718.3984375 MB
# iteration: 34
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000020742376297e-06 13846.669212632547 13846.66346838323
# dt: 970.7397373664754  max_vel: 1.0000000000000073e-09  Seconds: 2912.2172120994264   Days: 0.03370621773263225 year 9.234580200721164e-05
# Memory usage: 718.3984375 MB
# iteration: 35
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000021992128246e-06 20770.00381894882 20769.994683429122
# dt: 1456.1096060497132  max_vel: 1.0000000000000073e-09  Seconds: 4368.326818149139   Days: 0.050559338173022446 year 0.00013851873472060943
# Memory usage: 718.3984375 MB
# iteration: 36
# foward time taken: 0.006978 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.00000330889703e-06 31155.00572842323 31154.98511072298
# dt: 2184.16440907457  max_vel: 1.0000000000000073e-09  Seconds: 6552.491227223709   Days: 0.07583901883360773 year 0.00020777813379070612
# Memory usage: 718.3984375 MB
# iteration: 37
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000037044887467e-06 46732.50859263485 46732.47396870137
# dt: 3276.2466136118546  max_vel: 1.0000000000000073e-09  Seconds: 9828.737840835563   Days: 0.1137585398244857 year 0.0003116672323958512
# Memory usage: 718.4453125 MB
# iteration: 38
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000066490524686e-06 70098.76288895226 70098.66967125367
# dt: 4914.369920417782  max_vel: 1.0000000000000073e-09  Seconds: 14743.107761253345   Days: 0.1706378213108026 year 0.0004675008803035688
# Memory usage: 718.4453125 MB
# iteration: 39
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000412058138083e-06 105148.1443334284 105147.27781188017
# dt: 7371.5548806266725  max_vel: 1.0000000000000073e-09  Seconds: 22114.662641880015   Days: 0.2559567435402779 year 0.000701251352165145
# Memory usage: 718.5078125 MB
# iteration: 40
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000292846065864e-06 157722.2165001426 157721.2927497615
# dt: 11057.332320940008  max_vel: 1.0000000000000073e-09  Seconds: 33171.99496282003   Days: 0.38393512688449105 year 0.0010518770599575098
# Memory usage: 718.52734375 MB
# iteration: 41
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0001690607441118e-06 236583.32475021385 236575.32617095768
# dt: 16585.99848141001  max_vel: 1.0000000000000073e-09  Seconds: 49757.99344423004   Days: 0.5759027019008106 year 0.0015778156216460565
# Memory usage: 718.76953125 MB
# iteration: 42
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0001812908725827e-06 354874.98712532077 354862.12140553474
# dt: 24878.997722115015  max_vel: 1.0000000000000073e-09  Seconds: 74636.99116634505   Days: 0.8638540644252899 year 0.0023667234641788766
# Memory usage: 718.90234375 MB
# iteration: 43
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000511853938547e-06 532312.4806879811 532307.0315305348
# dt: 37318.49658317252  max_vel: 1.0000000000000073e-09  Seconds: 111955.48774951758   Days: 1.295781108212009 year 0.003550085227978107
# Memory usage: 718.90234375 MB
# iteration: 44
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000558040710374e-06 798468.7210319716 798459.8097692943
# dt: 55977.74487475878  max_vel: 1.0000000000000073e-09  Seconds: 167933.23262427637   Days: 1.9436716738920874 year 0.005325127873676952
# Memory usage: 719.01171875 MB
# iteration: 45
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000496012860987e-06 1197703.0815479576 1197691.2003789062
# dt: 83966.61731213817  max_vel: 1.0000000000000073e-09  Seconds: 251899.84993641454   Days: 2.9155075224122053 year 0.00798769184222522
# Memory usage: 719.01171875 MB
# iteration: 46
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000875538561487e-06 1796554.6223219363 1796523.1649174541
# dt: 125949.92596820726  max_vel: 1.0000000000000073e-09  Seconds: 377849.7759046218   Days: 4.373261295192382 year 0.011981537795047622
# Memory usage: 719.01171875 MB
# iteration: 47
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0001189899265703e-06 2694831.933482905 2694767.806490335
# dt: 188924.8889523109  max_vel: 1.0000000000000073e-09  Seconds: 566774.6648569327   Days: 6.559891954362647 year 0.017972306724281226
# Memory usage: 719.14453125 MB
# iteration: 48
# foward time taken: 0.005983 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0006499983629802e-06 4042247.900224357 4041722.614164075
# dt: 283387.33342846634  max_vel: 1.0000000000000073e-09  Seconds: 850161.998285399   Days: 9.839837943118045 year 0.02695846011813163
# Memory usage: 719.3046875 MB
# iteration: 49
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0001603328850644e-06 6063371.850336536 6063177.437458206
# dt: 425081.0001426995  max_vel: 1.0000000000000073e-09  Seconds: 1275242.9984280986   Days: 14.759756926251141 year 0.04043769020890724
# Memory usage: 719.3046875 MB
# iteration: 50
# foward time taken: 0.004986 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0000339921892378e-06 9095057.775504801 9094995.944580851
# dt: 637621.5002140492  max_vel: 1.0000000000000073e-09  Seconds: 1912864.498642148   Days: 22.139635400950784 year 0.06065653534507064
# Memory usage: 719.3046875 MB
# iteration: 51
# foward time taken: 0.003988 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0012042914205e-06 13642586.663257206 13639303.105478339
# dt: 956432.2503210739  max_vel: 1.0000000000000073e-09  Seconds: 2869296.748963222   Days: 33.20945311300026 year 0.09098480304931578
# Memory usage: 719.38671875 MB
# iteration: 52
# foward time taken: 0.004986 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.000189131451673e-06 20463879.994885806 20463106.010048456
# dt: 1434648.375481611  max_vel: 1.0000000000000073e-09  Seconds: 4303945.124444833   Days: 49.81417968107446 year 0.13647720460568344
# Memory usage: 719.38671875 MB
# iteration: 53
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0013026425665978e-06 30695819.992328707 30687829.10046246
# dt: 2151972.563222416  max_vel: 1.0000000000000073e-09  Seconds: 6455917.687667249   Days: 74.72126953318575 year 0.20471580694023492
# Memory usage: 719.41015625 MB
# iteration: 54
# foward time taken: 0.003988 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.0014000474071392e-06 46043729.98849306 46030848.12664775
# dt: 3227958.8448336245  max_vel: 1.0000000000000073e-09  Seconds: 9683876.532500874   Days: 112.08190431135272 year 0.3070737104420622
# Memory usage: 719.4296875 MB
# iteration: 55
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.002351826519792e-06 69065594.98273961 69033154.68519618
# dt: 4841938.267250437  max_vel: 1.0000000000000073e-09  Seconds: 14525814.799751312   Days: 168.12285647860315 year 0.4606105656948032
# Memory usage: 719.4296875 MB
# iteration: 56
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.028792187882644e-06 103598392.47410941 103011920.73629722
# dt: 7262907.400875656  max_vel: 1.0000000000000038e-09  Seconds: 21788722.20062697   Days: 252.1842847294788 year 0.6909158485739145
# Memory usage: 719.4296875 MB
# iteration: 57
# foward time taken: 0.004985 seconds
#
# condition1,condition2,hnew1,hnew2: 1e-06 1.000101504097022e-06 155397588.71116412 155394434.2048944
# dt: 10894361.101313483  max_vel: 1.0000000000000073e-09  Seconds: 32683083.301940452   Days: 378.27642710579227 year 1.0363737728925815
# Memory usage: 719.4296875 MB
# iteration: 58
# foward time taken: 0.005982 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0000013753445344e-06 1.000250565325387e-06 233096318.9492318 233084703.64834794
# dt: 16341541.651970224  max_vel: 1.0000000000000038e-09  Seconds: 49024624.95391068   Days: 567.4146406702624 year 1.554560659370582
# Memory usage: 719.4296875 MB
# iteration: 59
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0000013753445344e-06 1.0002816687949827e-06 349644478.42384773 349624881.1350151
# dt: 24512312.477955338  max_vel: 1.0000000000000145e-09  Seconds: 73536937.43186602   Days: 851.1219610169678 year 2.331840989087583
# Memory usage: 719.4296875 MB
# iteration: 60
# foward time taken: 0.004985 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0000013753445344e-06 1.0010024548670914e-06 524466717.6357716 524361774.22745615
# dt: 36768468.716933005  max_vel: 1.0000000000000286e-09  Seconds: 110305406.14879903   Days: 1276.682941537026 year 3.497761483663085
# Memory usage: 719.4296875 MB
# iteration: 61
# foward time taken: 0.004984 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0000027506890687e-06 1.0004049327296554e-06 786699860.0574034 786636596.1857505
# dt: 55152703.0753995  max_vel: 1.0000000000000855e-09  Seconds: 165458109.22419852   Days: 1915.0244123171124 year 5.246642225526335
# Memory usage: 719.4296875 MB
# iteration: 62
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 1.000028882235221e-06 1.0078352269999558e-06 1180043622.8946533 1178209890.329873
# dt: 82729054.61309925  max_vel: 1.0000000000009238e-09  Seconds: 248187163.83729777   Days: 2872.5366184872423 year 7.869963338321212
# Memory usage: 719.4296875 MB
# iteration: 63
# foward time taken: 0.004037 seconds
#
# condition1,condition2,hnew1,hnew2: 1.000398849914957e-06 1.0003691329140168e-06 1769934493.788321 1769945009.2107418
# dt: 124093581.91964887  max_vel: 1.0000000000051873e-09  Seconds: 372280745.7569466   Days: 4308.804927742438 year 11.80494500751353
# Memory usage: 719.4296875 MB
# iteration: 64
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0072494410404689e-06 1.0050609796470827e-06 2651280526.6726446 2652434123.9534683
# dt: 186140372.8794733  max_vel: 1.0000000000375026e-09  Seconds: 558421118.6364199   Days: 6463.20739162523 year 17.707417511302
# Memory usage: 719.4296875 MB
# iteration: 65
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 1.1191130887432209e-06 1.0001709526436572e-06 3894032331.148688 3982534076.9188495
# dt: 279210559.31920993  max_vel: 1.0000000009514027e-09  Seconds: 837631677.9556298   Days: 9694.81108744942 year 26.56112626698471
# Memory usage: 719.4296875 MB
# iteration: 66
# foward time taken: 0.002994 seconds
#
# condition1,condition2,hnew1,hnew2: 2.752921994686643e-06 1.0000742671165567e-06 4878730472.414951 5973916618.355227
# dt: 418815838.9788149  max_vel: 1.000000049627418e-09  Seconds: 1256447516.9344447   Days: 14542.216631185702 year 39.84168940050877
# Memory usage: 719.4296875 MB
# iteration: 67
# foward time taken: 0.007979 seconds
#
# condition1,condition2,hnew1,hnew2: 0.00011916525619853683 1.0001459447056335e-06 3444505923.6579194 8960746483.81369
# dt: 628223758.4682224  max_vel: 1.0000020414544884e-09  Seconds: 1884671275.402667   Days: 21813.32494679013 year 59.76253410079487
# Memory usage: 719.45703125 MB
# iteration: 68
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.42498321972482955 1.0055048531480502e-06 1006407277.8806607 13426762007.284903
# dt: 942335637.7023336  max_vel: 1.0036728477758637e-09  Seconds: 2827006913.1050005   Days: 32719.987420196765 year 89.64380115122401
# Memory usage: 719.45703125 MB
# iteration: 69
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 4705.8823475260015 4738.374666975243 166912193.7426721 166682650.83006296
# nrjct: 1   condition1, 4705.8823475260015  condition2: 4738.374666975243   dt: 503203638.9403303
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 5.90559846249622 9.009897644022153e-05 317492521.1782833 2917711257.6255064
# nrjct: 2   condition1, 5.90559846249622  condition2: 9.009897644022153e-05   dt: 317492521.1782833
# foward time taken: 0.006976 seconds
#
# condition1,condition2,hnew1,hnew2: 3.9797250205773405 1.0863084316369729e-06 216773103.7624378 4454360669.16683
# nrjct: 3   condition1, 3.9797250205773405  condition2: 1.0863084316369729e-06   dt: 216773103.7624378
# foward time taken: 0.004984 seconds
#
# condition1,condition2,hnew1,hnew2: 2.268006382674557 1.104658188385877e-06 165622391.31356248 3031114360.4004054
# nrjct: 4   condition1, 2.268006382674557  condition2: 1.104658188385877e-06   dt: 165622391.31356248
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 1.4663234254927844 1.047031114738861e-06 138075176.0806582 2340828749.5029135
# nrjct: 5   condition1, 1.4663234254927844  condition2: 1.047031114738861e-06   dt: 138075176.0806582
# foward time taken: 0.005979 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0779488049840327 1.027445595588603e-06 122416085.540499 1958873306.7510946
# nrjct: 6   condition1, 1.0779488049840327  condition2: 1.027445595588603e-06   dt: 122416085.540499
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8750557559107656 1.0194123395370055e-06 113155026.94112343 1739446277.920197
# dt: 122416085.540499  max_vel: 1.054946419555622e-09  Seconds: 2949422998.6454997   Days: 34136.84026210069 year 93.52558975917997
# Memory usage: 719.56640625 MB
# iteration: 70
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 24.536731161287296 0.36756418883457764 53697370.69599917 124408405.3422518
# nrjct: 1   condition1, 24.536731161287296  condition2: 0.36756418883457764   dt: 56577513.47056171
# foward time taken: 0.005980 seconds
#
# condition1,condition2,hnew1,hnew2: 5.981537819736534 3.1809653488366386e-05 35606049.85000065 403993686.83426875
# nrjct: 2   condition1, 5.981537819736534  condition2: 3.1809653488366386e-05   dt: 35606049.85000065
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 2.296523970840572 1.3245875264178734e-06 27136392.259570524 480120414.95496297
# nrjct: 3   condition1, 2.296523970840572  condition2: 1.3245875264178734e-06   dt: 27136392.259570524
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 1.313366545726539 1.0163170221464726e-06 23126900.286604088 385823590.17565984
# nrjct: 4   condition1, 1.313366545726539  condition2: 1.0163170221464726e-06   dt: 23126900.286604088
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9464145521145059 1.0302668189268483e-06 21044744.404311612 327921577.652453
# dt: 23126900.286604088  max_vel: 1.1044189259860027e-09  Seconds: 2972549898.9321036   Days: 34404.512719121565 year 94.25893895649745
# Memory usage: 719.56640625 MB
# iteration: 71
# foward time taken: 0.006981 seconds
#
# condition1,condition2,hnew1,hnew2: 1.5624569843429064 2.725511480265699e-06 17323057.660576854 245638570.7449636
# nrjct: 1   condition1, 1.5624569843429064  condition2: 2.725511480265699e-06   dt: 17323057.660576854
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0353606899114725 1.6726024859104013e-06 15482772.271821339 222940264.8923416
# nrjct: 2   condition1, 1.0353606899114725  condition2: 1.6726024859104013e-06   dt: 15482772.271821339
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.817882774702764 1.4099967081414399e-06 14506178.698003825 206180512.9298673
# dt: 15482772.271821339  max_vel: 1.1055200982818536e-09  Seconds: 2988032671.203925   Days: 34583.711472267656 year 94.74989444456892
# Memory usage: 719.56640625 MB
# iteration: 72
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8096811908578602 1.3063204011709032e-06 13618608.099694787 196148770.70536473
# dt: 14506178.698003825  max_vel: 1.1080594718487864e-09  Seconds: 3002538849.901929   Days: 34751.607059050104 year 95.20988235356192
# Memory usage: 719.56640625 MB
# iteration: 73
# foward time taken: 0.004987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6078567340100598 1.3186509118315148e-06 13539885.302610919 183801590.00457385
# dt: 13618608.099694787  max_vel: 1.0791032495115622e-09  Seconds: 3016157458.0016236   Days: 34909.22983798176 year 95.64172558351167
# Memory usage: 719.56640625 MB
# iteration: 74
# foward time taken: 0.008969 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5759228483602377 1.0755876761440465e-06 13607697.088046962 190339240.20182583
# dt: 13539885.302610919  max_vel: 1.0800035036591777e-09  Seconds: 3029697343.3042345   Days: 35065.94147342864 year 96.07107252994147
# Memory usage: 719.56640625 MB
# iteration: 75
# foward time taken: 0.005983 seconds
#
# condition1,condition2,hnew1,hnew2: 0.4209023502320873 1.0912539319501172e-06 14560988.955408324 190740087.8397978
# dt: 13607697.088046962  max_vel: 1.063199526022374e-09  Seconds: 3043305040.3922815   Days: 35223.43796750326 year 96.50256977398153
# Memory usage: 719.56640625 MB
# iteration: 76
# foward time taken: 0.004987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5006154635584036 1.044766897689265e-06 15049862.420351068 205887272.87024105
# dt: 14560988.955408324  max_vel: 1.075108826188094e-09  Seconds: 3057866029.3476896   Days: 35391.967932264924 year 96.96429570483541
# Memory usage: 719.56640625 MB
# iteration: 77
# foward time taken: 0.006981 seconds
#
# condition1,condition2,hnew1,hnew2: 0.48660181868505287 1.0896043545923363e-06 15643729.350469194 211018860.34465325
# dt: 15049862.420351068  max_vel: 1.0760933083624856e-09  Seconds: 3072915891.7680407   Days: 35566.156154722696 year 97.44152371156903
# Memory usage: 719.56640625 MB
# iteration: 78
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6412380093453988 1.1080706144283951e-06 15387885.697943874 218609643.2834751
# dt: 15643729.350469194  max_vel: 1.0990522026161183e-09  Seconds: 3088559621.11851   Days: 35747.21783701979 year 97.9375831151227
# Memory usage: 719.56640625 MB
# iteration: 79
# foward time taken: 0.005983 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6851230242806089 1.326113738610871e-06 14937150.218402097 207446115.1735747
# dt: 15387885.697943874  max_vel: 1.1072700378866793e-09  Seconds: 3103947506.8164535   Days: 35925.318365931176 year 98.42552976967445
# Memory usage: 719.56640625 MB
# iteration: 80
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8081901323970726 1.4485255031531277e-06 14028380.897558775 197844977.09670743
# dt: 14937150.218402097  max_vel: 1.1236987531383468e-09  Seconds: 3118884657.0348554   Days: 36098.20204901453 year 98.89918369593022
# Memory usage: 719.56640625 MB
# iteration: 81
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.7448729009802154 1.7032929417418803e-06 13391635.618562318 179883856.34553188
# dt: 14028380.897558775  max_vel: 1.1153566923154211e-09  Seconds: 3132913037.932414   Days: 36260.5675686622 year 99.34402073606081
# Memory usage: 719.5703125 MB
# iteration: 82
# foward time taken: 0.003990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.686171606715091 1.4148068512701814e-06 12995397.992688524 178211900.8080588
# dt: 13391635.618562318  max_vel: 1.105300805489106e-09  Seconds: 3146304673.5509763   Days: 36415.56335128444 year 99.76866671584779
# Memory usage: 719.5703125 MB
# iteration: 83
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5560961307510995 1.2283005220591106e-06 13152312.505529495 177898041.43347842
# dt: 12995397.992688524  max_vel: 1.089145765565866e-09  Seconds: 3159300071.543665   Days: 36565.973050273904 year 100.1807480829422
# Memory usage: 719.5703125 MB
# iteration: 84
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.47134045263069746 1.1124844132664031e-06 13758709.018616244 183647847.24591753
# dt: 13152312.505529495  max_vel: 1.078220198344741e-09  Seconds: 3172452384.0491943   Days: 36718.19888945827 year 100.597805176598
# Memory usage: 719.5703125 MB
# iteration: 85
# foward time taken: 0.005982 seconds
#
# condition1,condition2,hnew1,hnew2: 0.4467896012168013 1.0661394161453772e-06 14547875.777970776 193756997.2467965
# dt: 13758709.018616244  max_vel: 1.0794851025488612e-09  Seconds: 3186211093.0678105   Days: 36877.443206803364 year 101.03409097754346
# Memory usage: 719.5703125 MB
# iteration: 86
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.4495774671242102 1.0768693111792158e-06 15363182.380858274 204460535.2380224
# dt: 14547875.777970776  max_vel: 1.0837046516003332e-09  Seconds: 3200758968.8457813   Days: 37045.821398678025 year 101.49540109226857
# Memory usage: 719.5703125 MB
# iteration: 87
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5636954922093403 1.1000052428844672e-06 15506535.698167343 215003111.31121868
# dt: 15363182.380858274  max_vel: 1.1069587607609246e-09  Seconds: 3216122151.2266397   Days: 37223.63600956759 year 101.98256440977423
# Memory usage: 719.5703125 MB
# iteration: 88
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6475527961656005 1.3234335547534685e-06 15223070.411323557 209130253.7418857
# dt: 15506535.698167343  max_vel: 1.1220285964687057e-09  Seconds: 3231628686.924807   Days: 37403.109802370454 year 102.47427343115193
# Memory usage: 719.5703125 MB
# iteration: 89
# foward time taken: 0.004985 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8382119002972755 1.5742847054543216e-06 14192993.409428079 198302463.89887843
# dt: 15223070.411323557  max_vel: 1.1566459610316528e-09  Seconds: 3246851757.3361306   Days: 37579.302746945956 year 102.95699382724919
# Memory usage: 719.5703125 MB
# iteration: 90
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8005076090391823 2.7752874568659296e-06 13354985.402860167 165064969.4958123
# dt: 14192993.409428079  max_vel: 1.1580673179550285e-09  Seconds: 3261044750.7455587   Days: 37743.57350399953 year 103.40705069588911
# Memory usage: 719.5703125 MB
# iteration: 91
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8212066247493537 2.184624269605299e-06 12502458.978437174 162933571.10923907
# dt: 13354985.402860167  max_vel: 1.1570594247626e-09  Seconds: 3274399736.148419   Days: 37898.14509431041 year 103.83053450496001
# Memory usage: 719.5703125 MB
# iteration: 92
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6215786493397698 1.8050325659947442e-06 12374815.425896093 158467767.40671873
# dt: 12502458.978437174  max_vel: 1.1345793097250173e-09  Seconds: 3286902195.126856   Days: 38042.849480634904 year 104.22698487845179
# Memory usage: 719.5703125 MB
# iteration: 93
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5111276341287321 1.2434421222074641e-06 12737241.028901286 168988100.53636384
# dt: 12374815.425896093  max_vel: 1.117752458181197e-09  Seconds: 3299277010.552752   Days: 38186.076511027226 year 104.61938770144445
# Memory usage: 719.5703125 MB
# iteration: 94
# foward time taken: 0.004986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.45901337280008325 1.1108436350501099e-06 13395311.239620268 177904646.1983499
# dt: 12737241.028901286  max_vel: 1.1170143202607272e-09  Seconds: 3312014251.581653   Days: 38333.49828219506 year 105.02328296491798
# Memory usage: 719.5703125 MB
# iteration: 95
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.4824536926158882 1.071960297565752e-06 13947751.185173646 188434134.91797143
# dt: 13395311.239620268  max_vel: 1.1227793569091046e-09  Seconds: 3325409562.8212733   Days: 38488.5366067277 year 105.44804549788411
# Memory usage: 719.5703125 MB
# iteration: 96
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5323868726236576 1.0705550277931998e-06 14239712.89908932 196256885.1342057
# dt: 13947751.185173646  max_vel: 1.1489371614990898e-09  Seconds: 3339357314.006447   Days: 38649.96891211165 year 105.89032578660726
# Memory usage: 719.5703125 MB
# iteration: 97
# foward time taken: 0.005982 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6404648150374415 1.128865563635632e-06 14010211.366840186 198250959.35914493
# dt: 14239712.89908932  max_vel: 1.182193627912694e-09  Seconds: 3353597026.905536   Days: 38814.78040399926 year 106.34186412054592
# Memory usage: 719.5703125 MB
# iteration: 98
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.7053147722712849 1.2059973648366908e-06 13521055.667701067 192494322.6130272
# dt: 14010211.366840186  max_vel: 1.223910852724561e-09  Seconds: 3367607238.2723765   Days: 38976.9356281525 year 106.786125008637
# Memory usage: 719.5703125 MB
# iteration: 99
# foward time taken: 0.005980 seconds
#
# condition1,condition2,hnew1,hnew2: 0.7843822134585067 1.5548242274947446e-06 12774607.427754676 176569972.92568067
# dt: 13521055.667701067  max_vel: 1.2745639557879066e-09  Seconds: 3381128293.940078   Days: 39133.42932801016 year 107.21487487126072
# Memory usage: 719.5703125 MB
# iteration: 100
# foward time taken: 0.005962 seconds
#
# condition1,condition2,hnew1,hnew2: 0.7997012718906443 1.6853710850947364e-06 12022769.33468781 164153809.02335277
# dt: 12774607.427754676  max_vel: 1.3361471209649703e-09  Seconds: 3393902901.3678327   Days: 39281.28358064621 year 107.61995501546907
# Memory usage: 719.5703125 MB
# iteration: 101
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.7696089834199874 1.789039283337465e-06 11402314.056169663 152659223.50081247
# dt: 12022769.33468781  max_vel: 1.4092651808120073e-09  Seconds: 3405925670.7025204   Days: 39420.43600350139 year 108.0011945301408
# Memory usage: 719.5703125 MB
# iteration: 102
# foward time taken: 0.005982 seconds
#
# condition1,condition2,hnew1,hnew2: 0.7832396990955703 1.5022082142074254e-06 10775974.865698414 149930324.73946285
# dt: 11402314.056169663  max_vel: 1.4994493338714554e-09  Seconds: 3417327984.75869   Days: 39552.40723100336 year 108.3627595369955
# Memory usage: 719.5703125 MB
# iteration: 103
# foward time taken: 0.004985 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8659386131342588 1.18015283767477e-06 9981634.382590758 148700157.38896096
# dt: 10775974.865698414  max_vel: 1.60851869564962e-09  Seconds: 3428103959.624388   Days: 39677.12916231931 year 108.70446345840907
# Memory usage: 719.5703125 MB
# iteration: 104
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9244036992423726 1.064898168629619e-06 9125818.616214426 140599103.48220107
# dt: 9981634.382590758  max_vel: 1.7423478339262381e-09  Seconds: 3438085594.006979   Days: 39792.65733804374 year 109.02097900833901
# Memory usage: 719.5703125 MB
# iteration: 105
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9677720630788058 1.0323828097763877e-06 8267224.395666721 129343970.68648274
# dt: 9125818.616214426  max_vel: 1.9012487113925566e-09  Seconds: 3447211412.6231933   Days: 39898.280238694366 year 109.31035681834072
# Memory usage: 719.5703125 MB
# iteration: 106
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9959803240238904 1.0332971198132905e-06 7446498.10680883 117154018.90584686
# dt: 8267224.395666721  max_vel: 2.0945849328910015e-09  Seconds: 3455478637.01886   Days: 39993.965706236806 year 109.57250878421043
# Memory usage: 719.5703125 MB
# iteration: 107
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 1.017751285606561 1.031086300727667e-06 6678305.175601517 105568801.10770012
# nrjct: 1   condition1, 1.017751285606561  condition2: 1.031086300727667e-06   dt: 6678305.175601517
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8469545733065306 1.0238636732133474e-06 6213506.35550488 94811352.8449715
# dt: 6678305.175601517  max_vel: 2.2962436503522026e-09  Seconds: 3462156942.1944613   Days: 40071.26090502849 year 109.78427645213284
# Memory usage: 719.5703125 MB
# iteration: 108
# foward time taken: 0.004986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8956526866506688 1.0174165313304611e-06 5716778.028691937 88324156.45007485
# dt: 6213506.35550488  max_vel: 2.543861956713238e-09  Seconds: 3468370448.5499663   Days: 40143.17648784683 year 109.9813054461557
# Memory usage: 719.5703125 MB
# iteration: 109
# foward time taken: 0.004986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9364031182845762 1.0181691318129826e-06 5213162.576230309 81251213.12008175
# dt: 5716778.028691937  max_vel: 2.84280347492016e-09  Seconds: 3474087226.578658   Days: 40209.34290021595 year 110.16258328826287
# Memory usage: 719.5703125 MB
# iteration: 110
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9690006240161362 1.0231831244019383e-06 4721488.83478101 74020685.82309696
# dt: 5213162.576230309  max_vel: 3.211498397515905e-09  Seconds: 3479300389.1548886   Days: 40269.68043003343 year 110.32789158913269
# Memory usage: 719.5703125 MB
# iteration: 111
# foward time taken: 0.002992 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9994606767564564 1.0307616447484025e-06 4249798.453243125 66940634.80372505
# dt: 4721488.83478101  max_vel: 3.6658647826465943e-09  Seconds: 3484021877.98967   Days: 40324.3272915471 year 110.47760901793727
# Memory usage: 719.5703125 MB
# iteration: 112
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 1.026422172109511 1.0425602527985903e-06 3804920.9515372827 60116074.06383872
# nrjct: 1   condition1, 1.026422172109511  condition2: 1.0425602527985903e-06   dt: 3804920.9515372827
# foward time taken: 0.005980 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8622940202018146 1.036623860842191e-06 3527419.1892680107 53884506.26029832
# dt: 3804920.9515372827  max_vel: 4.160721177796294e-09  Seconds: 3487826798.941207   Days: 40368.36572848619 year 110.59826226982518
# Memory usage: 719.5703125 MB
# iteration: 113
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9173808651080347 1.047497236999563e-06 3229904.244072742 49850441.085036926
# dt: 3527419.1892680107  max_vel: 4.788686257875906e-09  Seconds: 3491354218.130475   Days: 40409.19233947309 year 110.71011599855642
# Memory usage: 719.5703125 MB
# iteration: 114
# foward time taken: 0.003990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9662336907371927 1.0653016109399378e-06 2926952.814973001 45492273.32788106
# dt: 3229904.244072742  max_vel: 5.591067462751267e-09  Seconds: 3494584122.374548   Days: 40446.57549044616 year 110.81253559026345
# Memory usage: 719.5703125 MB
# iteration: 115
# foward time taken: 0.004982 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0154931114603256 1.0918655087050297e-06 2626169.9909649566 41022715.13875341
# nrjct: 1   condition1, 1.0154931114603256  condition2: 1.0918655087050297e-06   dt: 2626169.9909649566
# foward time taken: 0.006977 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8624102906288014 1.0799723741767931e-06 2434571.6351443036 36887805.0972272
# dt: 2626169.9909649566  max_vel: 6.513292760184758e-09  Seconds: 3497210292.365513   Days: 40476.9709764527 year 110.89581089439096
# Memory usage: 719.5703125 MB
# iteration: 116
# foward time taken: 0.004985 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9287668304393703 1.1124842007459127e-06 2223738.5651658885 33994315.19396403
# dt: 2434571.6351443036  max_vel: 7.722100356673113e-09  Seconds: 3499644864.000657   Days: 40505.148888896496 year 110.97301065451094
# Memory usage: 719.5703125 MB
# iteration: 117
# foward time taken: 0.003988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9958615848808209 1.1737600809501536e-06 2003025.329927243 30719233.16051561
# dt: 2223738.5651658885  max_vel: 9.446693767692244e-09  Seconds: 3501868602.565823   Days: 40530.886603771105 year 111.04352494183864
# Memory usage: 719.5703125 MB
# iteration: 118
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0636703572396367 1.2858580814283638e-06 1780604.7989452828 27170044.082477793
# nrjct: 1   condition1, 1.0636703572396367  condition2: 1.2858580814283638e-06   dt: 1780604.7989452828
# foward time taken: 0.005980 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9002203164367663 1.2447172986393197e-06 1636591.4838561635 24310612.666777078
# dt: 1780604.7989452828  max_vel: 1.1557686978282209e-08  Seconds: 3503649207.3647685   Days: 40551.49545561075 year 111.09998754961849
# Memory usage: 719.5703125 MB
# iteration: 119
# foward time taken: 0.004982 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9858569903293657 1.4463507608953364e-06 1477134.400351183 21683434.414178185
# dt: 1636591.4838561635  max_vel: 1.492344515742314e-08  Seconds: 3505285798.8486247   Days: 40570.4374866739 year 111.15188352513398
# Memory usage: 719.5703125 MB
# iteration: 120
# foward time taken: 0.003988 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0812816858427428 3.256228254361515e-05 1308804.4180602927 10498313.892153975
# nrjct: 1   condition1, 1.0812816858427428  condition2: 3.256228254361515e-05   dt: 1308804.4180602927
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.9178807908143731 1.626774145218424e-05 1198284.6762528117 10686901.57246232
# dt: 1308804.4180602927  max_vel: 1.9630314390873596e-08  Seconds: 3506594603.266685   Days: 40585.585685957 year 111.19338544097808
# Memory usage: 719.5703125 MB
# iteration: 121
# foward time taken: 0.002995 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0264107656752663 0.004154038358940695 1072848.1960525953 3229300.1629192117
# nrjct: 1   condition1, 1.0264107656752663  condition2: 0.004154038358940695   dt: 1072848.1960525953
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.885557863800554 0.0014374982457015211 989321.3830074054 3574862.317908536
# dt: 1072848.1960525953  max_vel: 2.6785913199741243e-08  Seconds: 3507667451.4627376   Days: 40598.00291044835 year 111.22740523410506
# Memory usage: 719.5703125 MB
# iteration: 122
# foward time taken: 0.003991 seconds
#
# condition1,condition2,hnew1,hnew2: 1.0141525224145924 3.505738708138236 887890.17507832 692825.711765472
# nrjct: 1   condition1, 1.0141525224145924  condition2: 3.505738708138236   dt: 692825.711765472
# foward time taken: 0.005980 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6327269236291208 0.07306153668831998 683318.6010307507 1052273.771644344
# dt: 692825.711765472  max_vel: 3.053429952979143e-08  Seconds: 3508360277.174503   Days: 40606.02172655675 year 111.24937459330616
# Memory usage: 719.5703125 MB
# iteration: 123
# foward time taken: 0.004987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.7293646111081611 0.11943003951578877 655053.565726226 940682.4406958974
# dt: 683318.6010307507  max_vel: 4.054346462632235e-08  Seconds: 3509043595.7755337   Days: 40613.930506661265 year 111.27104248400346
# Memory usage: 719.5703125 MB
# iteration: 124
# foward time taken: 0.003990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.8525319969841734 5.631485607930674 608663.3989653232 417248.4468537351
# nrjct: 1   condition1, 0.8525319969841734  condition2: 5.631485607930674   dt: 417248.4468537351
# foward time taken: 0.002986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.4686415688875086 0.19415008461971703 436987.56275249226 521206.3777957142
# dt: 417248.4468537351  max_vel: 3.872404538238113e-08  Seconds: 3509460844.2223873   Days: 40618.759771092446 year 111.28427334545876
# Memory usage: 719.5703125 MB
# iteration: 125
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5424679201690638 0.0017995042485319894 444464.1877608708 1392133.905031963
# dt: 436987.56275249226  max_vel: 4.3686323745837245e-08  Seconds: 3509897831.78514   Days: 40623.81749751319 year 111.29813013017312
# Memory usage: 719.5703125 MB
# iteration: 126
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6421706188572066 0.003582770845740605 437068.18750830326 1233773.6112048593
# dt: 444464.1877608708  max_vel: 5.702737483241388e-08  Seconds: 3510342295.972901   Days: 40628.96175894561 year 111.31222399711126
# Memory usage: 719.5703125 MB
# iteration: 127
# foward time taken: 0.002984 seconds
#
# condition1,condition2,hnew1,hnew2: 0.7834286187531333 1.4957846188023434 413039.7222603741 362925.842657079
# nrjct: 1   condition1, 0.7834286187531333  condition2: 1.4957846188023434   dt: 362925.842657079
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6135727086742145 0.1784585372443202 360153.13247662666 461055.213752979
# dt: 362925.842657079  max_vel: 7.163609151972276e-08  Seconds: 3510705221.815558   Days: 40633.16228953192 year 111.32373230008746
# Memory usage: 719.58203125 MB
# iteration: 128
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.7355932135410149 5.0550983461083945 344668.9515893609 234414.12868357205
# nrjct: 1   condition1, 0.7355932135410149  condition2: 5.0550983461083945   dt: 234414.12868357205
# foward time taken: 0.005980 seconds
#
# condition1,condition2,hnew1,hnew2: 0.4162477602492649 0.15260938831400997 251394.5808103885 307262.8419869169
# dt: 234414.12868357205  max_vel: 7.116507184528095e-08  Seconds: 3510939635.9442415   Days: 40635.875416021314 year 111.33116552334606
# Memory usage: 719.58203125 MB
# iteration: 129
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5103284649403399 0.007432739787180067 258838.2544838291 603071.2642304249
# dt: 251394.5808103885  max_vel: 8.284008150041518e-08  Seconds: 3511191030.525052   Days: 40638.78507552144 year 111.33913719320942
# Memory usage: 719.58203125 MB
# iteration: 130
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.622174584045164 0.05640689339759706 256146.55462357227 414003.9984270037
# dt: 258838.2544838291  max_vel: 1.1705486637884048e-07  Seconds: 3511449868.779536   Days: 40641.780888652036 year 111.34734490041653
# Memory usage: 719.58203125 MB
# iteration: 131
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.7945423359442529 6.8297171949374045 241383.52187021347 156982.22631143796
# nrjct: 1   condition1, 0.7945423359442529  condition2: 6.8297171949374045   dt: 156982.22631143796
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 0.4174390280124779 1.2722582001609204 168257.48119371882 134641.19006380497
# ...
# dt: 0.013551678009619636  max_vel: 0.4708641690537966  Seconds: 3512883705.131839   Days: 40658.37621680369 year 111.39281155288683
# Memory usage: 719.9296875 MB
# iteration: 452
# foward time taken: 0.002993 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6080116268994167 0.3232609726951711 0.013390833823928947 0.015194252608684266
# dt: 0.01346937635796449  max_vel: 0.4731137491123384  Seconds: 3512883705.145308   Days: 40658.37621695958 year 111.39281155331392
# Memory usage: 719.9296875 MB
# iteration: 453
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.607473748900691 0.3226454300292022 0.013315105964600985 0.015111411304741718
# dt: 0.013390833823928947  max_vel: 0.4753380118368117  Seconds: 3512883705.158699   Days: 40658.37621711457 year 111.39281155373855
# Memory usage: 719.9296875 MB
# iteration: 454
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6059064653846369 0.3214844242459854 0.013246648702658364 0.015036790506676372
# dt: 0.013315105964600985  max_vel: 0.47753673446664835  Seconds: 3512883705.172014   Days: 40658.376217268684 year 111.39281155416077
# Memory usage: 719.9296875 MB
# iteration: 455
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6036961676471337 0.3219523214123429 0.01318817935450579 0.014955130819574815
# dt: 0.013246648702658364  max_vel: 0.4797104356906951  Seconds: 3512883705.185261   Days: 40658.376217421996 year 111.3928115545808
# Memory usage: 719.9296875 MB
# iteration: 456
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6063402191429679 0.32394824784492726 0.01311849695805481 0.014870727901005935
# dt: 0.01318817935450579  max_vel: 0.4818600633657026  Seconds: 3512883705.198449   Days: 40658.376217574645 year 111.39281155499903
# Memory usage: 719.9296875 MB
# iteration: 457
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6085786183692421 0.3248034852480851 0.01303956940802113 0.01478435738288948
# dt: 0.01311849695805481  max_vel: 0.48398304580605017  Seconds: 3512883705.2115674   Days: 40658.37621772647 year 111.392811555415
# Memory usage: 719.9296875 MB
# iteration: 458
# foward time taken: 0.004982 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6087933190122575 0.3245768905208115 0.012960202408508162 0.014697458438081838
# dt: 0.01303956940802113  max_vel: 0.48607718303498354  Seconds: 3512883705.224607   Days: 40658.3762178774 year 111.39281155582849
# Memory usage: 719.9296875 MB
# iteration: 459
# foward time taken: 0.005982 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6076978312503137 0.32390722440959363 0.012885959333065399 0.014614035796124466
# dt: 0.012960202408508162  max_vel: 0.48814174824330836  Seconds: 3512883705.2375674   Days: 40658.3762180274 year 111.39281155623945
# Memory usage: 719.9296875 MB
# iteration: 460
# foward time taken: 0.005482 seconds
#
# condition1,condition2,hnew1,hnew2: 0.606801477677988 0.3239088579879508 0.012815924489499784 0.014530304008917428
# dt: 0.012885959333065399  max_vel: 0.4901769173728199  Seconds: 3512883705.2504535   Days: 40658.37621817654 year 111.39281155664806
# Memory usage: 719.9296875 MB
# iteration: 461
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6066088071393054 0.3238423037185607 0.012747079872341265 0.014451926138777861
# dt: 0.012815924489499784  max_vel: 0.4921827011257793  Seconds: 3512883705.2632694   Days: 40658.37621832488 year 111.39281155705446
# Memory usage: 719.9296875 MB
# iteration: 462
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6061733153769168 0.32386538781877916 0.012680426284066411 0.014374088326949742
# dt: 0.012747079872341265  max_vel: 0.494291629978176  Seconds: 3512883705.2760167   Days: 40658.37621847241 year 111.39281155745866
# Memory usage: 719.9296875 MB
# iteration: 463
# foward time taken: 0.005982 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6061303975364217 0.32350041978721067 0.012614299849486931 0.014302152134861211
# dt: 0.012680426284066411  max_vel: 0.496605150450683  Seconds: 3512883705.2886972   Days: 40658.37621861918 year 111.39281155786077
# Memory usage: 719.9296875 MB
# iteration: 464
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6049080048961841 0.32250044552928625 0.012553585745911916 0.014236380790635706
# dt: 0.012614299849486931  max_vel: 0.49890028436475686  Seconds: 3512883705.3013115   Days: 40658.37621876518 year 111.39281155826077
# Memory usage: 719.9296875 MB
# iteration: 465
# foward time taken: 0.006979 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6029271048696949 0.32110011624305035 0.012501362286852318 0.014180195231396336
# dt: 0.012553585745911916  max_vel: 0.5011775481608701  Seconds: 3512883705.313865   Days: 40658.376218910475 year 111.39281155865883
# Memory usage: 719.9296875 MB
# iteration: 466
# foward time taken: 0.006979 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6004801002861673 0.31945681637231604 0.012459486005924393 0.014135703224972415
# dt: 0.012501362286852318  max_vel: 0.5034379907750559  Seconds: 3512883705.3263664   Days: 40658.37621905517 year 111.39281155905526
# Memory usage: 719.9296875 MB
# iteration: 467
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5977566542758634 0.3176725676958578 0.01242904476506696 0.014104142702516179
# dt: 0.012459486005924393  max_vel: 0.5056829582274138  Seconds: 3512883705.3388257   Days: 40658.376219199374 year 111.39281155945034
# Memory usage: 719.9296875 MB
# iteration: 468
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5948776319809247 0.3160798766769256 0.012410655880496379 0.014083833824958624
# dt: 0.01242904476506696  max_vel: 0.5079139426897935  Seconds: 3512883705.351255   Days: 40658.37621934323 year 111.39281155984446
# Memory usage: 719.9296875 MB
# iteration: 469
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5933776366043295 0.3176296585300552 0.012398553156456037 0.014049246539591186
# dt: 0.012410655880496379  max_vel: 0.5101324867805751  Seconds: 3512883705.3636656   Days: 40658.37621948687 year 111.392811560238
# Memory usage: 719.9296875 MB
# iteration: 470
# foward time taken: 0.005982 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5964397711345191 0.32152484496512984 0.012373717562978429 0.014001372509707486
# dt: 0.012398553156456037  max_vel: 0.5123390216135282  Seconds: 3512883705.3760643   Days: 40658.37621963037 year 111.39281156063116
# Memory usage: 719.9296875 MB
# iteration: 471
# foward time taken: 0.005048 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6035534625065732 0.3250542685312519 0.012319683737796367 0.013942849305409313
# dt: 0.012373717562978429  max_vel: 0.5145305002551049  Seconds: 3512883705.388438   Days: 40658.37621977359 year 111.39281156102354
# Memory usage: 719.9296875 MB
# iteration: 472
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6072000001984724 0.3266013162749747 0.01225111780235242 0.013868787132650285
# dt: 0.012319683737796367  max_vel: 0.5167009289458668  Seconds: 3512883705.400758   Days: 40658.37621991618 year 111.39281156141419
# Memory usage: 719.9296875 MB
# iteration: 473
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.608325426297154 0.32679161646951327 0.012178422353423054 0.01378999294615554
# dt: 0.01225111780235242  max_vel: 0.51884698246906  Seconds: 3512883705.4130087   Days: 40658.37622005797 year 111.39281156180266
# Memory usage: 719.9296875 MB
# iteration: 474
# foward time taken: 0.005980 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6078036197530585 0.32620573664691754 0.012108236205710778 0.01371308670915995
# dt: 0.012178422353423054  max_vel: 0.5209671983583831  Seconds: 3512883705.425187   Days: 40658.37622019892 year 111.39281156218883
# Memory usage: 719.9296875 MB
# iteration: 475
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6064891257092185 0.3251486469180776 0.012043668421139107 0.01364290967248637
# dt: 0.012108236205710778  max_vel: 0.5232786310942573  Seconds: 3512883705.4372954   Days: 40658.376220339065 year 111.39281156257279
# Memory usage: 719.9296875 MB
# iteration: 476
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6045247913435184 0.3236946121273009 0.011987220016464455 0.013582327735337126
# dt: 0.012043668421139107  max_vel: 0.5256548725713479  Seconds: 3512883705.449339   Days: 40658.37622047846 year 111.39281156295468
# Memory usage: 719.9296875 MB
# iteration: 477
# foward time taken: 0.004986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.602063537897847 0.3219830346830586 0.011940775157258408 0.013533009545138499
# dt: 0.011987220016464455  max_vel: 0.5280123959829868  Seconds: 3512883705.461326   Days: 40658.3762206172 year 111.3928115633348
# Memory usage: 719.9296875 MB
# iteration: 478
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5993104620530573 0.32223814390586586 0.011905418280161654 0.013478440341638507
# dt: 0.011940775157258408  max_vel: 0.5303526146006096  Seconds: 3512883705.473267   Days: 40658.3762207554 year 111.39281156371344
# Memory usage: 719.9296875 MB
# iteration: 479
# foward time taken: 0.002989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6008192656114344 0.3237788166220832 0.011864198322048356 0.01342571678406462
# dt: 0.011905418280161654  max_vel: 0.532677122588727  Seconds: 3512883705.4851723   Days: 40658.376220893195 year 111.39281156409095
# Memory usage: 719.9296875 MB
# iteration: 480
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6039938939194025 0.3269612479056768 0.011810666258898834 0.013353086143593972
# dt: 0.011864198322048356  max_vel: 0.5349841360982226  Seconds: 3512883705.4970365   Days: 40658.376221030514 year 111.39281156446717
# Memory usage: 719.9296875 MB
# iteration: 481
# foward time taken: 0.002991 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6083896248432077 0.3289020957937677 0.011740336564265466 0.01327711077832206
# dt: 0.011810666258898834  max_vel: 0.537270611938403  Seconds: 3512883705.508847   Days: 40658.376221167215 year 111.39281156484168
# Memory usage: 719.9296875 MB
# iteration: 482
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6099853930858341 0.3293276248429378 0.011664313121986106 0.013194636314482562
# dt: 0.011740336564265466  max_vel: 0.539544483071832  Seconds: 3512883705.5205874   Days: 40658.37622130309 year 111.39281156521396
# Memory usage: 719.9296875 MB
# iteration: 483
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6097397138666523 0.3287618921811887 0.011589715693265973 0.013113704243450363
# dt: 0.011664313121986106  max_vel: 0.5417931626111873  Seconds: 3512883705.532252   Days: 40658.3762214381 year 111.39281156558383
# Memory usage: 719.9296875 MB
# iteration: 484
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6083092519435731 0.3279056699967638 0.011521006125045169 0.01303663500888502
# dt: 0.011589715693265973  max_vel: 0.5440156911324343  Seconds: 3512883705.5438414   Days: 40658.37622157224 year 111.39281156595133
# Memory usage: 719.9296875 MB
# iteration: 485
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.606987604091413 0.32695134172071405 0.011457686960243789 0.012966903898286654
# dt: 0.011521006125045169  max_vel: 0.5462126412406388  Seconds: 3512883705.555362   Days: 40658.376221705585 year 111.39281156631667
# Memory usage: 719.9296875 MB
# iteration: 486
# foward time taken: 0.003987 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6052367156616583 0.3255879802351659 0.011401300931765343 0.012906419865706979
# dt: 0.011457686960243789  max_vel: 0.5483844677632155  Seconds: 3512883705.56682   Days: 40658.376221838196 year 111.39281156668
# Memory usage: 719.9296875 MB
# iteration: 487
# foward time taken: 0.003988 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6028875108408661 0.32391149872377517 0.011354020154201911 0.012856171141960238
# dt: 0.011401300931765343  max_vel: 0.5505318962580351  Seconds: 3512883705.5782213   Days: 40658.37622197015 year 111.39281156704152
# Memory usage: 719.9296875 MB
# iteration: 488
# foward time taken: 0.004986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6001795231678034 0.32205204411688654 0.011317120377625164 0.012817607196400294
# dt: 0.011354020154201911  max_vel: 0.5526560297761308  Seconds: 3512883705.5895753   Days: 40658.376222101564 year 111.39281156740155
# Memory usage: 720.08984375 MB
# iteration: 489
# foward time taken: 0.003989 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5972669099673575 0.32009321329922263 0.011291320996196327 0.012791549376882665
# dt: 0.011317120377625164  max_vel: 0.5547581619979637  Seconds: 3512883705.6008925   Days: 40658.37622223255 year 111.39281156776042
# Memory usage: 720.08984375 MB
# iteration: 490
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5942468714521738 0.31808760023767096 0.011277007846125474 0.01277844227570882
# dt: 0.011291320996196327  max_vel: 0.5568396585344443  Seconds: 3512883705.612184   Days: 40658.376222363244 year 111.39281156811847
# Memory usage: 720.08984375 MB
# iteration: 491
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.591179054433822 0.3160673934635084 0.01127437781466093 0.012778516940759472
# dt: 0.011277007846125474  max_vel: 0.558958990597448  Seconds: 3512883705.6234612   Days: 40658.37622249376 year 111.39281156847605
# Memory usage: 720.08984375 MB
# iteration: 492
# foward time taken: 0.005979 seconds
#
# condition1,condition2,hnew1,hnew2: 0.588098619987048 0.3140515013170767 0.011283531917223859 0.012791895974080831
# dt: 0.01127437781466093  max_vel: 0.5612220460834245  Seconds: 3512883705.6347356   Days: 40658.376222624254 year 111.39281156883358
# Memory usage: 720.08984375 MB
# iteration: 493
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5850249446534636 0.3120502884020855 0.011304534778827272 0.012818660736558999
# dt: 0.011283531917223859  max_vel: 0.5635474554355849  Seconds: 3512883705.646019   Days: 40658.37622275485 year 111.39281156919137
# Memory usage: 720.08984375 MB
# iteration: 494
# foward time taken: 0.003004 seconds
#
# condition1,condition2,hnew1,hnew2: 0.5849737097895347 0.32027807146578896 0.011325775117541438 0.012775848783461571
# dt: 0.011304534778827272  max_vel: 0.5659018447200769  Seconds: 3512883705.6573234   Days: 40658.37622288569 year 111.39281156954982
# Memory usage: 720.08984375 MB
# iteration: 495
# foward time taken: 0.003986 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6007557942481969 0.3284447782255266 0.011286800530260504 0.012735557799972121
# dt: 0.011325775117541438  max_vel: 0.5682493991895828  Seconds: 3512883705.668649   Days: 40658.37622301677 year 111.39281156990896
# Memory usage: 720.09375 MB
# iteration: 496
# foward time taken: 0.003009 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6101037797600118 0.3330738111721064 0.011213278694353125 0.012656256328260122
# dt: 0.011286800530260504  max_vel: 0.5705768071917873  Seconds: 3512883705.679936   Days: 40658.3762231474 year 111.39281157026686
# Memory usage: 720.09375 MB
# iteration: 497
# foward time taken: 0.007912 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6149781331393025 0.33525105088883117 0.011122519886214398 0.012557439546857507
# dt: 0.011213278694353125  max_vel: 0.5728763077414727  Seconds: 3512883705.691149   Days: 40658.37622327719 year 111.39281157062244
# Memory usage: 720.09375 MB
# iteration: 498
# foward time taken: 0.002990 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6168184341599523 0.3357723057679433 0.011025904624185725 0.012451931581602748
# dt: 0.011122519886214398  max_vel: 0.575143865607066  Seconds: 3512883705.702272   Days: 40658.376223405925 year 111.39281157097514
# Memory usage: 720.09375 MB
# iteration: 499
# foward time taken: 0.004983 seconds
#
# condition1,condition2,hnew1,hnew2: 0.6166483665256156 0.33520239963714415 0.010930731431495007 0.012347962932162027
# dt: 0.011025904624185725  max_vel: 0.5773778779336775  Seconds: 3512883705.713298   Days: 40658.37622353354 year 111.39281157132476
# Memory usage: 720.09375 MB
# 26

# %%
# Check all member variables for class sim0
print(dir(sim0))
# Out:
# ['A0', 'A1d', 'A1s', 'A2d', 'A2s', 'Batch_size', 'Bd', 'Bs', 'Cs', 'GetTtstress', 'Init_condition', 'Init_condition1', 'InputHetoparamter', 'Para0', 'Relerrormax1_last', 'Relerrormax2_last', 'RungeKutte_solve_Dormand_Prince', 'RungeKutte_solve_Dormand_Prince_gpu', 'T_globalarr', 'Tno', 'Tt', 'Tt1o', 'Tt2o', 'V0', 'Vpl_con', 'Vpld', 'Vpls', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'a', 'arriT', 'ave_elesize', 'b', 'calc_corefunc', 'calc_nucleaszie_cohesivezone', 'dc', 'density', 'derivative', 'derivative_gpu', 'dirname', 'eleVec', 'elelst', 'f0', 'fix_Tn', 'fric', 'get_coreAB', 'get_coreAB_mulproess', 'get_coreAB_mulproess1', 'get_coreAB_mulproess1_', 'get_coreAB_mulproess2', 'get_coreAB_mulproess2_', 'get_rotation1', 'get_value', 'hRA', 'halfspace_jud', 'htry', 'initGPUvariable', 'lambda_', 'localTra', 'maxsize', 'maxslipv0', 'maxslipvque', 'mu', 'nodelst', 'normal_loading', 'num_process', 'ouputVTK', 'outputtxt', 'rake', 'rake0', 'randompatch', 'read_parameter', 'shear_loading', 'shear_loadingD', 'shear_loadingS', 'simu_forward', 'simu_forwardGPU', 'slip', 'slip1', 'slip2', 'slipv', 'slipv1', 'slipv2', 'slipvC', 'state', 'time', 'useGPU', 'val_nv', 'vec_Tra', 'worker', 'worker1', 'worker2', 'xg']

# %% [markdown]
# ## Step 6: Visualize Results
#
# The simulation generates VTK files, visualize them using PyVista.You can also output all results in your own format by accessing the member variables of sim0(e.g. sim0.slip).

# %%
import pyvista as pv
import glob
import os

# set vtk file path
folder_path = "../outvtk/"  

vtk_files = glob.glob(os.path.join(folder_path, "*.vtk")) + glob.glob(os.path.join(folder_path, "*.vtu"))


#read state file for time show
def is_number(s):
    try:
        float(s) 
        return True
    except ValueError:
        return False

def readstate(fname):
    f=open(fname,'r')
    K=0
    data0=[]
    for line in f:
        tem=line.split()
        
        if(len(tem)==6 and is_number(tem[0])==True):
            data0.append(np.array(tem).astype(float))
    return np.array(data0)
state=readstate('state.txt')
print(state.shape)

# # show one figure 
plotter = pv.Plotter(off_screen=True)
mesh = pv.read(vtk_files[10])
plotter.add_mesh(mesh, scalars='Shear_[MPa]', cmap="viridis", show_edges=False)  # show shear stress

#plotter.camera_position = [(0, -5, 0), (0, 0, 0), (0, 0, 1)]
plotter.show()

# create animation
outsteps=int(sim0.Para0['outsteps'])
plotter = pv.Plotter(off_screen=True)
plotter.open_gif('animation.gif')  # Initialize GIF output

for i, vtk_file in enumerate(vtk_files):
    mesh = pv.read(folder_path+'step'+str(i*outsteps)+'.vtk')
    plotter.clear()  # Clear previous mesh
    plotter.add_mesh(
        mesh,
        scalars='Shear_[MPa]',  #output shear stress, many variables such as (slip, slipv) can be used.
        cmap="viridis",
        show_edges=False,
    )
    timeyear=state[i*outsteps,-1]/365
    plotter.add_text(f"Time: {timeyear}", position="upper_left", font_size=14, color="white", shadow=True)
    plotter.write_frame()  # Write frame to GIF

plotter.close()
print('Video has been saved in src folder.')
# Out:
# (502, 6)
# D:\Anaconda3\envs\testquake\Lib\site-packages\pyvista\jupyter\notebook.py:56: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
# Video has been saved in src folder.

# %% [markdown]
# ## GPU acceleration
# Install cupy if you want to use GPU acceleration, we recommened to use conda in prompt terminal (e.g. CUDA 11.8):conda install -c conda-forge cupy cudatoolkit=11.8
#
# **Notes**:
# CuPy relies on NVIDIA CUDA for GPU computing, so the following components are required:
#
# 1. **NVIDIA GPU Driver**:
# Ensure your system has a CUDA-capable NVIDIA GPU (check compatibility at https://developer.nvidia.com/cuda-gpus).
# The driver version must support the CUDA Toolkit version used by CuPy (e.g., CUDA 10.2–12.x for CuPy v13.x).
#
# 2. **CUDA Toolkit**:
# CuPy supports specific CUDA versions (check the latest compatibility at https://docs.cupy.dev/en/stable/install.html).
# Common versions: CUDA 11.8 or 12.2 are widely used.

# %%
import cupy as cp
print(cp.cuda.is_available())  # check CUDA availble
print(cp.cuda.runtime.getDeviceCount())
# Out:
# True
# 1

# %% [markdown]
# The GPU operates in a similar way to the CPU, only the output is converted to numpy each time.
#
# **Note**: Make sure to set GPU:True in the parameter.txt

# %%
start_time=time.time()
    
totaloutputsteps=int(sim0.Para0['totaloutputsteps'])
directory='../outvtk'
if not os.path.exists(directory):
    os.mkdir(directory)

f=open('state.txt','w')
f.write('iteration time_step(s) maximum_slip1_rate(m/s) maximum_slip2_rate(m/s) time(s) time(h)\n')


if(sim0.useGPU==True): #GPU case
    sim0.initGPUvariable()
    
    for i in range(totaloutputsteps):
        print('iteration:',i)
        if(i==0):
            dttry=sim0.htry
        else:
            dttry=dtnext
        dttry,dtnext=sim0.simu_forwardGPU(dttry)
        # transform from cupy to numpy variables
        sim0.slipv1=sim0.slipv1_gpu.get()
        sim0.slipv2=sim0.slipv2_gpu.get()
        sim0.slipv=sim0.slipv_gpu.get()
        sim0.slip=sim0.slip_gpu.get()
        sim0.Tt1o=sim0.Tt1o_gpu.get()
        sim0.Tt2o=sim0.Tt2o_gpu.get()
        sim0.Tt=sim0.Tt_gpu.get()
        #sim0.state1=sim0.state1_gpu.get()
        #sim0.state2=sim0.state2_gpu.get()
        sim0.rake=sim0.rake_gpu.get()
        year=sim0.time/3600/24/365

        print('dt:',dttry,' Seconds:',sim0.time,'  Days:',sim0.time/3600/24,'year',year)
        print(' max_vel1:',np.max(np.abs(sim0.slipv1)),' max_vel2:',np.max(np.abs(sim0.slipv2)),' min_Tt1:',np.min(sim0.Tt1o),' min_Tt2:',np.min(sim0.Tt2o))  
        f.write('%d %f %.16e %.16e %f %f\n' %(i,dttry,np.max(np.abs(sim0.slipv1)),np.max(np.abs(sim0.slipv2)),sim0.time,sim0.time/3600.0/24.0))

        memory_info = process.memory_info()
        print(f"Memory usage: {memory_info.rss / (1024 ** 2)} MB")

        if(sim0.Para0['outputvtk']=='True'):
            outsteps=int(sim0.Para0['outsteps'])#output steps
            if(i%outsteps==0):
                fname=directory+'/step'+str(i)+'.vtk'
                sim0.ouputVTK(fname)

# %% [markdown]
# ## For MPI version on Linux system
#
# ## Step 1: Set Up Conda environment
# 1. Download latest Miniconda3
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O miniconda.sh
#
# 2. Install Miniconda with the following command:
# bash miniconda.sh -b -u -p ~/miniconda3
#
# Parameters:
#
# -b: Batch mode, automatically accepts the license agreement.
# -u: Updates the installation if the directory already exists.
# -p ~/miniconda3: Specifies the installation directory (here, miniconda3 in the home directory).
#
# 4. After installation, initialize Conda for terminal use:
# ~/miniconda3/bin/conda init
#
# 5. Close and reopen the terminal, or run:
# source ~/.bashrc
#
# 6. Verify the Installation,Check the Conda version:
# conda --version
#
# 7. After installation, create a new environment:
# conda create -n PyQuake3D python=3.12
#
# 8. Activate the environment:
# conda activate PyQuake3D
#
#
# **Notes**:Dependencies: Ensure wget is installed. If not, install it:
# bashsudo apt install wget  # For Ubuntu/Debian
# sudo yum install wget  # For CentOS/RHEL

# %% [markdown]
# ## Step 2: Install Python and C++ Dependencies
#
# **For MPI-CPU verison in Linux (e.g. ubantu)**
# 1. Download from https://github.com/Computational-Geophysics/PyQuake3D
# 2. Install an MPI implementation and g++ compiler(including gcc and other related tools). Common options are:
# - sudo apt update
# - sudo apt install g++
# - sudo apt install openmpi-bin libopenmpi-dev
#
# 3. Install PyQuake3D using pip: pip install -r requirements (make sure PyQuake3D environment is activated).
# 4. Navigate to the src directory, run make to build TDstressFS_C.so.The generated library is called by the Python script Hmatrix.py via dynamic loading (e.g., using ctypes).
#
# **Notes1**:MPI-CPU version is recommended for use on Linux because it requires compiling a C dynamic library, which used for green's function calculation acceleration. Compiling C dynamic libraries (DLLs) on Windows can be less convenient compared to Linux or other Unix-like systems for several reasons, stemming from differences in tooling, ecosystem, and system design.
#
# **Notes2**:PyQuake3D supports Python 3.8 and above, so there is no need to specify a specific version when installing the library in the requirement.txt.

# %% [markdown]
# ## Step 3: Explore Examples for MPI-based PyQuake3D
#
#
# To execute benchmarks like BP5-QD, use:
# ```bash
# In the PyQuake3D_MPI_V2 directory, To run the BP5-QD benchmark:
# mpirun -np 10 python src/main.py -g examples/BP5-QD/bp5t.msh -p examples/BP5-QD/parameter.txt
# Ensure you modify the input parameter (`parameter.txt`) as follows:
# - `Corefunc directory`: `bp5t_core`
# - `InputHetoparamter`: `True`
# - `Inputparamter file`: `bp5tparam.dat`
#
# To run the **HF-model**:
# mpirun -np 10 python src/main.py -g examples/HF-model/HFmodel.msh -p examples/HF-model/parameter.txt
#
# To run the  **EAFZ-model**:
# mpirun -np 10 python src/main.py -g examples/EAFZ-model/turkey.msh -p examples/EAFZ-model/parameter.txt
#
# To run the  **Lab-model**:
# mpirun -np 10 python src/main.py -g examples/Lab-model/lab.msh -p examples/Lab-model/parameter.txt
#
#
#
# Run these in a Linux terminal.

# %% [markdown]
# ## Additional Notes
#
# - **Performance:** Use more CPUs (`-np`) or multithreaded parallelism in parameter.txt.
# - **Help:** Contact authors at rongjiang@csj.uestc.edu.cn or luca.dalzilio@ntu.edu.sg.
# - **Manual:** Refer to the Code Manual PDF for detailed parameter info.
#
# Save this notebook and run cells sequentially. For advanced usage, explore `src/` or modify parameters for custom simulations.
